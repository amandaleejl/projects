# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# The ACT and SAT tests are used as a measure of college readiness and used as a gauge for admission into college through these tests. The ACT includes an English Test, Reading Test, Mathematics Test and a Science Test. The SAT includes a Reading Test, Writing and Language Test and a Math Test. In recent years, the **ACT has had a higher frequency of full participation (100%) for more states as compared to the participation for the SATs.**
#
# We are a non profit organisation with the goal to connect students to college success and expand access to higher education. With the interest to promote the participation of SATs, we aim to devise a strategic plan that targets areas where lower rates of participation for both tests are observed.
#
# As such, to come up with an appropriate and targeted solution, we have decided to analyse the **SAT and ACT participation data** and **average scores by states** in 2017 and 2018.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# sat_2017 contains the participation of each individual state. It includes the average score of students that took the evidence-based reading and writing, and math test. The data set contains objects and integers.
#
# act_2017 contains the participation of each individual state. The data set contains objects and floats of the average scores for English, Math, Reading, Science and Composite data.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# Yes.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# SAT (0, 1800)
#
# ACT (1, 36)

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
#code

sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# For the SAT dataset, participation is an object, when it should be an float.
#
# For the ACT dataset, participation and composite are objects when they should be an floats.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
#for SAT - changing 'Participation' column to float
sat_2017['Participation']= sat_2017['Participation'].str.replace(r'%', r'').astype('float')/100
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
#for ACT - changing 'Participation' column to float
act_2017['Participation']=act_2017['Participation'].str.replace(r'%', r'').astype('float')/100
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
#for SAT - editing data for Maryland from 52 to 524
sat_2017['Math']=sat_2017['Math'].replace(52,524)

# %%
#for ACT - editing data for Maryland from 52 to 524
act_2017['Science']=act_2017['Science'].replace(2.3,23.2)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_2017
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National           0.60     20.3  20.7     21.4     21.0
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
# 11               Georgia           0.55     21.0  20.9     22.0     21.3
# ...

# %%
#code
act_2017['Composite'].tail()
# Out:
# 47     23.8
# 48     21.9
# 49     20.4
# 50     20.5
# 51    20.2x
# Name: Composite, dtype: object

# %%
act_2017['Composite']= act_2017['Composite'].str.replace(r'x', r'').astype('float')

# %%
act_2017.tail()
# Out:
#             State  Participation  English  Math  Reading  Science  Composite
# 47       Virginia           0.29     23.5  23.3     24.6     23.5       23.8
# 48     Washington           0.29     20.9  21.9     22.1     22.0       21.9
# 49  West Virginia           0.69     20.0  19.4     21.2     20.5       20.4
# 50      Wisconsin           1.00     19.7  20.4     20.6     20.9       20.5
# 51        Wyoming           1.00     19.4  19.8     20.8     20.6       20.2

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2017.rename(columns={'State':'state', 
                         'Participation':'sat_2017_participation',
                         'Evidence-Based Reading and Writing':'sat_2017_ewb',
                         'Math':'sat_2017_math',
                         'Total':'sat_2017_total'},inplace=True)

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act_2017.rename(columns={'State':'state', 
                         'Participation':'act_2017_participation',
                         'English':'act_2017_english',
                         'Math':'act_2017_math',
                         'Reading':'act_2017_reading',
                         'Science':'act_2017_science',
                         'Composite':'act_2017_comp'},inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|Feature|Type|Dataset|Description|
# |---|---|---|---|---|---|---|---|
# |act_2017_participation |float|ACT|State ACT Participation percentage, 2017|act_2018_updated_participation|float|ACT|State ACT Participation percentage, 2018|
# |act_2017_english |float|ACT|State mean score for ACT English, 2017|act_2018_updated_english|float|ACT|State mean score for ACT English, 2018|
# |act_2017_math|float|ACT|State mean score for ACT Math, 2017|act_2018_updated_math|float|ACT|State mean score for ACT Math, 2018|
# |act_2017_reading|float|ACT|State mean score for ACT Reading, 2017|act_2018_updated_reading|float|ACT|State mean score for ACT Reading, 2018|
# |act_2017_science|float|ACT|State mean score for ACT Science, 2017|act_2018_updated_science|float|ACT|State mean score for ACT Science, 2018|
# |act_2017_comp|float|ACT|State mean score for ACT Composite, 2017|act_2018_updated_comp|float|ACT|State mean score for ACT Composite, 2018|
# |sat_2017_participation|float|SAT|State SAT Participation percentage, 2017|sat_2018_participation|float|SAT|State SAT Participation percentage, 2018|
# |sat_2017_ewb|int|SAT|State mean score for SAT Evidence-based reading and Writing, 2017|sat_2018_ewb|int|SAT|State mean score for SAT Evidence-based reading and Writing, 2018|
# |sat_2017_math|int|SAT|State mean score for SAT Math, 2017|sat_2018_math|int|SAT|State mean score for SAT Math, 2018|
# |sat_2017_total|int|SAT|State mean score for average total score for SAT, 2017|sat_2018_total|int|SAT|State mean score for average total score for SAT, 2018|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
#drop National from ACT dataframe

act_2017.drop([0], inplace=True)

# %%
act_2017.head()
# Out:
#         state  act_2017_participation  act_2017_english  act_2017_math  \
# 1     Alabama                    1.00              18.9           18.4
# 2      Alaska                    0.65              18.7           19.8
# 3     Arizona                    0.62              18.6           19.8
# 4    Arkansas                    1.00              18.9           19.0
# 5  California                    0.31              22.5           22.7
#
#    act_2017_reading  act_2017_science  act_2017_comp
# 1              19.7              19.4           19.2
# 2              20.4              19.9           19.8
# 3              20.1              19.8           19.7
# 4              19.7              19.5           19.4
# 5              23.1              22.2           22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:

combined_2017 = pd.merge(act_2017,sat_2017,on='state', how='outer')

# %%
combined_2017.head()
# Out:
#         state  act_2017_participation  act_2017_english  act_2017_math  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_2017_reading  act_2017_science  act_2017_comp  sat_2017_participation  \
# 0              19.7              19.4           19.2                    0.05
# 1              20.4              19.9           19.8                    0.38
# 2              20.1              19.8           19.7                    0.30
# 3              19.7              19.5           19.4                    0.03
# 4              23.1              22.2           22.8                    0.53
#
#    sat_2017_ewb  sat_2017_math  sat_2017_total
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code

combined_2017.to_csv('../data/combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#import data
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
act_2018_updated = pd.read_csv('../data/act_2018_updated.csv')

# %%
act_2018_updated.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
sat_2018['State'].value_counts().head()
# Out:
# Connecticut      1
# Texas            1
# West Virginia    1
# Oklahoma         1
# Maryland         1
# Name: State, dtype: int64

# %%
act_2018['State'].value_counts().head()
# Out:
# Maine            2
# Florida          1
# Missouri         1
# West Virginia    1
# Oklahoma         1
# Name: State, dtype: int64

# %%
act_2018_updated['State'].value_counts().head()
# Out:
# Connecticut      1
# Texas            1
# West Virginia    1
# Oklahoma         1
# Maryland         1
# Name: State, dtype: int64

# %%
act_2018[act_2018['State'].isin(['Maine'])]
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %%
act_2018.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
act_2018.reset_index(drop=True)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#for SAT_2018 - changing 'Participation' column to float
sat_2018['Participation']= sat_2018['Participation'].str.replace(r'%', r'').astype('float')/100
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
#for ACT_2018 - changing 'Participation' column to float
act_2018['Participation']=act_2018['Participation'].str.replace(r'%', r'').astype('float')/100
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
#for ACT_2018_updated - changing 'Participation' column to float
act_2018_updated['Percentage of Students Tested']=act_2018_updated['Percentage of Students Tested'].astype('float')/100
act_2018_updated.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                           1.00                     19.1
# 1      Alaska                           0.33                     20.8
# 2     Arizona                           0.66                     19.2
# 3    Arkansas                           1.00                     19.4
# 4  California                           0.27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
#renaming SAT_2018 headings
sat_2018.rename(columns={'State':'state', 
                         'Participation':'sat_2018_participation',
                         'Evidence-Based Reading and Writing':'sat_2018_ewb',
                         'Math':'sat_2018_math',
                         'Total':'sat_2018_total'},inplace=True)

# %%
#renaming ACT_2018 headings
act_2018.rename(columns={'State':'state', 
                         'Participation':'act_2018_participation',
                         'Composite':'act_2018_comp'},inplace=True)

# %%
#renaming ACT_2018_updated headings
act_2018_updated.rename(columns={'State':'state',
                                 'Percentage of Students Tested':'act_2018_updated_participation',
                                 'Average Composite Score':'act_2018_updated_comp',
                                 'Average English Score':'act_2018_updated_english',
                                 'Average Math Score':'act_2018_updated_math', 
                                 'Average Reading Score':'act_2018_updated_reading',
                                 'Average Science Score':'act_2018_updated_science'},inplace=True)

# %%
act_2018_updated.head()
# Out:
#         state  act_2018_updated_participation  act_2018_updated_comp  \
# 0     Alabama                            1.00                   19.1
# 1      Alaska                            0.33                   20.8
# 2     Arizona                            0.66                   19.2
# 3    Arkansas                            1.00                   19.4
# 4  California                            0.27                   22.7
#
#    act_2018_updated_english  act_2018_updated_math  act_2018_updated_reading  \
# 0                      18.9                   18.3                      19.6
# 1                      19.8                   20.6                      21.6
# 2                      18.2                   19.4                      19.5
# 3                      19.1                   18.9                      19.7
# 4                      22.5                   22.5                      23.0
#
#    act_2018_updated_science
# 0                      19.0
# 1                      20.7
# ...

# %%
#combining SAT_2018 and ACT_2018 to one dataframe
combined_2018 = pd.merge(act_2018,sat_2018, on='state', how='outer')

# %%
#combining SAT_2018 and ACT_2018_updated to one dataframe
combined_2018_updated = pd.merge(act_2018_updated,sat_2018,on='state', how='outer')

# %%
#combining combined_2017 and combined_2018 into final dataframe
final = pd.merge(combined_2017, combined_2018, on='state', how='outer')

# %%
#combining combined_2017 and combined_2018_updated into final dataframe
final_updated = pd.merge(combined_2017, combined_2018_updated, on='state', how='outer')

# %%
#exporting data to csv
final.to_csv('../data/final.csv', index=False)

# %%
#exporting final_updated to csv
final_updated.to_csv('../data/final_updated.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:

final.describe()
# Out:
#        act_2017_participation  act_2017_english  act_2017_math  \
# count               51.000000         51.000000      51.000000
# mean                 0.652549         20.931373      21.182353
# std                  0.321408          2.353677       1.981989
# min                  0.080000         16.300000      18.000000
# 25%                  0.310000         19.000000      19.400000
# 50%                  0.690000         20.700000      20.900000
# 75%                  1.000000         23.300000      23.100000
# max                  1.000000         25.500000      25.300000
#
#        act_2017_reading  act_2017_science  act_2017_comp  \
# count         51.000000         51.000000      51.000000
# mean          22.013725         21.450980      21.519608
# std            2.067271          1.739353       2.020695
# min           18.100000         18.200000      17.800000
# 25%           20.450000         19.950000      19.800000
# ...

# %%
final_updated.describe().T
# Out:
#                                 count         mean        std     min  \
# act_2017_participation           51.0     0.652549   0.321408    0.08
# act_2017_english                 51.0    20.931373   2.353677   16.30
# act_2017_math                    51.0    21.182353   1.981989   18.00
# act_2017_reading                 51.0    22.013725   2.067271   18.10
# act_2017_science                 51.0    21.450980   1.739353   18.20
# act_2017_comp                    51.0    21.519608   2.020695   17.80
# sat_2017_participation           51.0     0.398039   0.352766    0.02
# sat_2017_ewb                     51.0   569.117647  45.666901  482.00
# sat_2017_math                    51.0   556.882353  47.121395  468.00
# sat_2017_total                   51.0  1126.098039  92.494812  950.00
# act_2018_updated_participation   51.0     0.616471   0.340810    0.07
# act_2018_updated_comp            51.0    21.486275   2.106278   17.70
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def stddev(X):
    mean = sum(X)/len(X)
    var = 0.0
    for i in X:
        var = var + (i - mean)**2
    return (var/len(X))**0.5

# %%
stddev(final_updated['act_2017_english'])
# Out:
# 2.3304876369363363

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:

{X.name:stddev(X) for X in [final_updated[i] for i in final_updated.columns if (final_updated[i].dtype=='float64') or (final_updated[i].dtype=='int64')]}
# Out:
# {'act_2017_participation': 0.3182417575123181,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7222161451443676,
#  'act_2017_comp': 2.000786081581989,
#  'sat_2017_participation': 0.3492907076664507,
#  'sat_2017_ewb': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_updated_participation': 0.33745194881997503,
#  'act_2018_updated_comp': 2.0855261815801147,
#  'act_2018_updated_english': 2.4222536143202795,
#  'act_2018_updated_math': 2.015707255555717,
#  'act_2018_updated_reading': 2.145891884510421,
#  'act_2018_updated_science': 1.8516885484833543,
#  'sat_2018_participation': 0.3694661922353942,
#  'sat_2018_ewb': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %%
np.std(final_updated)
# Out:
# act_2017_participation             0.318242
# act_2017_english                   2.330488
# act_2017_math                      1.962462
# act_2017_reading                   2.046903
# act_2017_science                   1.722216
# act_2017_comp                      2.000786
# sat_2017_participation             0.349291
# sat_2017_ewb                      45.216970
# sat_2017_math                     46.657134
# sat_2017_total                    91.583511
# act_2018_updated_participation     0.337452
# act_2018_updated_comp              2.085526
# act_2018_updated_english           2.422254
# act_2018_updated_math              2.015707
# act_2018_updated_reading           2.145892
# act_2018_updated_science           1.851689
# sat_2018_participation             0.369466
# sat_2018_ewb                      47.034610
# sat_2018_math                     47.301946
# sat_2018_total                    93.227424
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer
#
# The calculated standard deviations match up with numpy's std method instead of the output from pandas describe.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code
final_updated.head(10)
# Out:
#                   state  act_2017_participation  act_2017_english  \
# 0               Alabama                    1.00              18.9
# 1                Alaska                    0.65              18.7
# 2               Arizona                    0.62              18.6
# 3              Arkansas                    1.00              18.9
# 4            California                    0.31              22.5
# 5              Colorado                    1.00              20.1
# 6           Connecticut                    0.31              25.5
# 7              Delaware                    0.18              24.1
# 8  District of Columbia                    0.32              24.4
# 9               Florida                    0.73              19.0
#
#    act_2017_math  act_2017_reading  act_2017_science  act_2017_comp  \
# 0           18.4              19.7              19.4           19.2
# 1           19.8              20.4              19.9           19.8
# ...

# %%
#grouping columns
participation = final_updated[['state',
                       'sat_2017_participation',
                       'sat_2018_participation',
                       'act_2017_participation',
                       'act_2018_updated_participation']]

# %%
#sat_2017 - lowest participation
participation.sort_values(by=['sat_2017_participation']
                          ,ascending=True).head()
# Out:
#            state  sat_2017_participation  sat_2018_participation  \
# 34  North Dakota                    0.02                    0.02
# 24   Mississippi                    0.02                    0.03
# 15          Iowa                    0.02                    0.03
# 25      Missouri                    0.03                    0.04
# 44          Utah                    0.03                    0.04
#
#     act_2017_participation  act_2018_updated_participation
# 34                    0.98                            0.98
# 24                    1.00                            1.00
# 15                    0.67                            0.68
# 25                    1.00                            1.00
# 44                    1.00                            1.00

# %%
#sat_2017 - highest participation
participation.sort_values(by=['sat_2017_participation']
                          ,ascending=False).head()
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 8   District of Columbia                    1.00                    0.92
# 22              Michigan                    1.00                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 29         New Hampshire                    0.96                    0.96
#
#     act_2017_participation  act_2018_updated_participation
# 8                     0.32                            0.32
# 22                    0.29                            0.22
# 6                     0.31                            0.26
# 7                     0.18                            0.17
# 29                    0.18                            0.16

# %% [markdown]
# North Dakota is seen to have one of the lowest percentages for SAT participation at 2% for both 2017 and 2018, but yet high ACT participation for 2017, 2018.
#
# District of Columbia and Michigan have high percentages for SAT participation at 100% for both 2017 and 2018, but a relatively low participation for ACT.

# %%
#sat_2018 - lowest participation
participation.sort_values(by=['sat_2018_participation']
                          ,ascending=True).head(10)
# Out:
#            state  sat_2017_participation  sat_2018_participation  \
# 34  North Dakota                    0.02                    0.02
# 50       Wyoming                    0.03                    0.03
# 41  South Dakota                    0.03                    0.03
# 27      Nebraska                    0.03                    0.03
# 49     Wisconsin                    0.03                    0.03
# 24   Mississippi                    0.02                    0.03
# 15          Iowa                    0.02                    0.03
# 44          Utah                    0.03                    0.04
# 23     Minnesota                    0.03                    0.04
# 18     Louisiana                    0.04                    0.04
#
#     act_2017_participation  act_2018_updated_participation
# 34                    0.98                            0.98
# 50                    1.00                            1.00
# 41                    0.80                            0.77
# ...

# %%
#sat_2018 - highest participation
participation.sort_values(by=['sat_2018_participation']
                          ,ascending=False).head(10)
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 5               Colorado                    0.11                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 22              Michigan                    1.00                    1.00
# 12                 Idaho                    0.93                    1.00
# 19                 Maine                    0.95                    0.99
# 13              Illinois                    0.09                    0.99
# 39          Rhode Island                    0.71                    0.97
# 29         New Hampshire                    0.96                    0.96
# 8   District of Columbia                    1.00                    0.92
#
#     act_2017_participation  act_2018_updated_participation
# 5                     1.00                            0.30
# ...

# %% [markdown]
# The highest percentage for SAT 2018, is by Colorado, Connecticut, Delaware, Michigan, Idaho. Connecticut, Delaware, Michigan and Idaho have maintained their high participation in the SATs. For Colorado, there seemed to be a statewide shift from taking the ACTs in 2017 to taking the SATs in 2018.
#
# North Dakota continues to have low state participation for the SATs as compared to the ACTs.

# %%
#act_2017 - lowest participation
participation.sort_values(by=['act_2017_participation']
                          ,ascending=True).head(10)
# Out:
#             state  sat_2017_participation  sat_2018_participation  \
# 19          Maine                    0.95                    0.99
# 29  New Hampshire                    0.96                    0.96
# 7        Delaware                    1.00                    1.00
# 39   Rhode Island                    0.71                    0.97
# 38   Pennsylvania                    0.65                    0.70
# 20       Maryland                    0.69                    0.76
# 45        Vermont                    0.60                    0.64
# 21  Massachusetts                    0.76                    0.80
# 22       Michigan                    1.00                    1.00
# 46       Virginia                    0.65                    0.68
#
#     act_2017_participation  act_2018_updated_participation
# 19                    0.08                            0.07
# 29                    0.18                            0.16
# 7                     0.18                            0.17
# ...

# %%
#act_2017 - highest participation
participation.sort_values(by=['act_2017_participation']
                          ,ascending=False).head(10)
# Out:
#              state  sat_2017_participation  sat_2018_participation  \
# 0          Alabama                    0.05                    0.06
# 17        Kentucky                    0.04                    0.04
# 49       Wisconsin                    0.03                    0.03
# 44            Utah                    0.03                    0.04
# 42       Tennessee                    0.05                    0.06
# 40  South Carolina                    0.50                    0.55
# 36        Oklahoma                    0.07                    0.08
# 33  North Carolina                    0.49                    0.52
# 28          Nevada                    0.26                    0.23
# 26         Montana                    0.10                    0.10
#
#     act_2017_participation  act_2018_updated_participation
# 0                      1.0                             1.0
# 17                     1.0                             1.0
# ...

# %% [markdown]
# Maine has the lowest percentage of state participation for the ACTs in both 2017 and 2018, but high percentages of state participation fro the SATs.
#
# The opposite is true for Alabama with high percentage for the ACTs and lower for the SATs in both 2017 and 2018.
#
# Overall, more states have a higher percentage at 100% participation for the ACTs as compared to the SATs.

# %%
#act_2018 - lowest participation
participation.sort_values(by=['act_2018_updated_participation']
                          ,ascending=True).head(10)
# Out:
#             state  sat_2017_participation  sat_2018_participation  \
# 19          Maine                    0.95                    0.99
# 39   Rhode Island                    0.71                    0.97
# 29  New Hampshire                    0.96                    0.96
# 7        Delaware                    1.00                    1.00
# 38   Pennsylvania                    0.65                    0.70
# 22       Michigan                    1.00                    1.00
# 47     Washington                    0.64                    0.69
# 45        Vermont                    0.60                    0.64
# 46       Virginia                    0.65                    0.68
# 21  Massachusetts                    0.76                    0.80
#
#     act_2017_participation  act_2018_updated_participation
# 19                    0.08                            0.07
# 39                    0.21                            0.15
# 29                    0.18                            0.16
# ...

# %%
#act_2018 - highest participation
participation.sort_values(by=['act_2018_updated_participation']
                          ,ascending=False).head(10)
# Out:
#              state  sat_2017_participation  sat_2018_participation  \
# 0          Alabama                    0.05                    0.06
# 17        Kentucky                    0.04                    0.04
# 49       Wisconsin                    0.03                    0.03
# 44            Utah                    0.03                    0.04
# 42       Tennessee                    0.05                    0.06
# 40  South Carolina                    0.50                    0.55
# 36        Oklahoma                    0.07                    0.08
# 35            Ohio                    0.12                    0.18
# 33  North Carolina                    0.49                    0.52
# 28          Nevada                    0.26                    0.23
#
#     act_2017_participation  act_2018_updated_participation
# 0                     1.00                             1.0
# 17                    1.00                             1.0
# ...

# %%
#sat_2017 - lowest total
final_updated.loc[: ,['sat_2017_total','state','sat_2017_participation']].sort_values(['sat_2017_total']
                ,ascending=True).head()
# Out:
#     sat_2017_total                 state  sat_2017_participation
# 8              950  District of Columbia                    1.00
# 7              996              Delaware                    1.00
# 12            1005                 Idaho                    0.93
# 22            1005              Michigan                    1.00
# 19            1012                 Maine                    0.95

# %%
#sat_2017 - highest total
final_updated.loc[: ,['sat_2017_total','state','sat_2017_participation']].sort_values(['sat_2017_total']
                ,ascending=False).head()
# Out:
#     sat_2017_total      state  sat_2017_participation
# 23            1295  Minnesota                    0.03
# 49            1291  Wisconsin                    0.03
# 15            1275       Iowa                    0.02
# 25            1271   Missouri                    0.03
# 16            1260     Kansas                    0.04

# %% [markdown]
# District of Columbia has the lowest SAT 2017 total score, the SAT 2017 participation is 100%.
#
# Minnesota has the highest SAT 2017 total score, but a very low SAT 2017 participation at 3%.
#
# Higher scores seem to have a lower participation rate. Could indicate selection bias where only students that did better in school, chose to do the SATS as well.

# %%
#sat_2018 - lowest total
final_updated.loc[: ,['sat_2018_total','state','sat_2018_participation']].sort_values(['sat_2018_total']
                ,ascending=True).head()
# Out:
#     sat_2018_total                 state  sat_2018_participation
# 8              977  District of Columbia                    0.92
# 7              998              Delaware                    1.00
# 48             999         West Virginia                    0.28
# 12            1001                 Idaho                    1.00
# 44            1010                  Utah                    0.04

# %%
#sat_2018 - highest total
final_updated.loc[: ,['sat_2018_total','state','sat_2018_participation']].sort_values(['sat_2018_total']
                ,ascending=False).head()
# Out:
#     sat_2018_total         state  sat_2018_participation
# 23            1298     Minnesota                    0.04
# 49            1294     Wisconsin                    0.03
# 34            1283  North Dakota                    0.02
# 15            1265          Iowa                    0.03
# 16            1265        Kansas                    0.04

# %%
#act_2017 - lowest comp
final_updated.loc[: ,['act_2017_comp','state','act_2017_participation']].sort_values(['act_2017_comp']
                ,ascending=True).head()
# Out:
#     act_2017_comp           state  act_2017_participation
# 28           17.8          Nevada                     1.0
# 24           18.6     Mississippi                     1.0
# 40           18.7  South Carolina                     1.0
# 11           19.0          Hawaii                     0.9
# 33           19.1  North Carolina                     1.0

# %%
#act_2017 - highest comp
final_updated.loc[: ,['act_2017_comp','state','act_2017_participation']].sort_values(['act_2017_comp']
                ,ascending=False).head()
# Out:
#     act_2017_comp                 state  act_2017_participation
# 29           25.5         New Hampshire                    0.18
# 21           25.4         Massachusetts                    0.29
# 6            25.2           Connecticut                    0.31
# 19           24.3                 Maine                    0.08
# 8            24.2  District of Columbia                    0.32

# %%
final_updated
# Out:
#                    state  act_2017_participation  act_2017_english  \
# 0                Alabama                    1.00              18.9
# 1                 Alaska                    0.65              18.7
# 2                Arizona                    0.62              18.6
# 3               Arkansas                    1.00              18.9
# 4             California                    0.31              22.5
# 5               Colorado                    1.00              20.1
# 6            Connecticut                    0.31              25.5
# 7               Delaware                    0.18              24.1
# 8   District of Columbia                    0.32              24.4
# 9                Florida                    0.73              19.0
# 10               Georgia                    0.55              21.0
# 11                Hawaii                    0.90              17.8
# 12                 Idaho                    0.38              21.9
# ...

# %%
#act_2018 - highest comp
final_updated.loc[: ,['act_2018_updated_comp','state','act_2018_updated_participation']].sort_values(['act_2018_updated_comp']
                ,ascending=True).head()
# Out:
#     act_2018_updated_comp           state  act_2018_updated_participation
# 28                   17.7          Nevada                            1.00
# 40                   18.3  South Carolina                            1.00
# 24                   18.6     Mississippi                            1.00
# 11                   18.9          Hawaii                            0.89
# 0                    19.1         Alabama                            1.00

# %%
#act_2018 - highest comp
final_updated.loc[: ,['act_2018_updated_comp','state','act_2018_updated_participation']].sort_values(['act_2018_updated_comp']
                ,ascending=True).head()
# Out:
#     act_2018_updated_comp           state  act_2018_updated_participation
# 28                   17.7          Nevada                            1.00
# 40                   18.3  South Carolina                            1.00
# 24                   18.6     Mississippi                            1.00
# 11                   18.9          Hawaii                            0.89
# 0                    19.1         Alabama                            1.00

# %% [markdown]
# **Highest and lowest participation rates:**
#
# | |**2017 SAT**| |**2018 SAT**|
# |---|---|---|---|
# |**Highest:**|District of Columbia, Michigan, Connecticut, Delawar|**Highest:**|Colorado, Connecticut, Delaware, Michigan, Idaho|
# |**Lowest:**|North Dakota, Mississipi, Iowa|**Lowest:**|North Dakota|
#
#
# | |**2017 ACT**| |**2018 ACT**|
# |---|---|---|---|
# |**Highest:**|Alabama, Kentucky, Wisconsin, Utah, Tennessee|**Highest:**|Alabama, Kentucky, Wisconsin, Utah, Tennessee|
# |**Lowest:**| Maine|**Lowest:**|Maine|
#
# **Highest and lowest mean total/composite scores:**
#
# | |**2017 SAT**| |**2018 SAT**|
# |---|---|---|---|
# |**Highest Total:**| Minnesota - 1295|**Highest Total:**|Minnesota - 1298|
# |**Lowest Total:**| District of Columbia - 950|**Lowest Total:**| Delaware - 998|
#
#
# | |**2017 ACT**| |**2018 ACT?**|
# |---|---|---|---|
# |**Highest Comp:**| New Hampshire - 25.5|**Highest Comp:**| Connecticut - 25.6|
# |**Lowest Comp:**| Nevada - 17.8|**Lowest Comp:**| Nevada - 17.7|

# %%
#Do any states with 100% participation on a SAT have a rate change year-to-year?

final_updated.loc[: ,['state','sat_2017_participation',
                      'sat_2018_participation',
                      'act_2017_participation',
                      'act_2018_updated_participation']].sort_values(['sat_2017_participation'],
                                                             ascending=False).head()
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 8   District of Columbia                    1.00                    0.92
# 22              Michigan                    1.00                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 29         New Hampshire                    0.96                    0.96
#
#     act_2017_participation  act_2018_updated_participation
# 8                     0.32                            0.32
# 22                    0.29                            0.22
# 6                     0.31                            0.26
# 7                     0.18                            0.17
# 29                    0.18                            0.16

# %% [markdown]
# District of Columbia's SAT participation in 2018 decreased as compared to 2017.

# %%
#Do any states with 100% participation on a ACT have a rate change year-to-year?

final_updated.loc[: ,['state','sat_2017_participation',
                      'sat_2018_participation',
                      'act_2017_participation',
                      'act_2018_updated_participation']].sort_values(['act_2017_participation'],
                                                             ascending=False).head()
# Out:
#         state  sat_2017_participation  sat_2018_participation  \
# 0     Alabama                    0.05                    0.06
# 17   Kentucky                    0.04                    0.04
# 49  Wisconsin                    0.03                    0.03
# 44       Utah                    0.03                    0.04
# 42  Tennessee                    0.05                    0.06
#
#     act_2017_participation  act_2018_updated_participation
# 0                      1.0                             1.0
# 17                     1.0                             1.0
# 49                     1.0                             1.0
# 44                     1.0                             1.0
# 42                     1.0                             1.0

# %% [markdown]
# State participation with a 100% on the ACTs did not change from 2017 to 2018.

# %%
#Do any states show have >50% participation on SATs either year?
participation[(participation.sat_2017_participation >= 0.50) & (participation.sat_2018_participation >= 0.50)]
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 4             California                    0.53                    0.60
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 8   District of Columbia                    1.00                    0.92
# 9                Florida                    0.83                    0.56
# 10               Georgia                    0.61                    0.70
# 11                Hawaii                    0.55                    0.56
# 12                 Idaho                    0.93                    1.00
# 14               Indiana                    0.63                    0.63
# 19                 Maine                    0.95                    0.99
# 20              Maryland                    0.69                    0.76
# 21         Massachusetts                    0.76                    0.80
# ...

# %%
#Do any states show have >50% participation on ACTs either year?
participation[(participation.act_2017_participation >= 0.50) & (participation.act_2018_updated_participation >= 0.50)]
# Out:
#              state  sat_2017_participation  sat_2018_participation  \
# 0          Alabama                    0.05                    0.06
# 2          Arizona                    0.30                    0.29
# 3         Arkansas                    0.03                    0.05
# 9          Florida                    0.83                    0.56
# 10         Georgia                    0.61                    0.70
# 11          Hawaii                    0.55                    0.56
# 15            Iowa                    0.02                    0.03
# 16          Kansas                    0.04                    0.04
# 17        Kentucky                    0.04                    0.04
# 18       Louisiana                    0.04                    0.04
# 23       Minnesota                    0.03                    0.04
# 24     Mississippi                    0.02                    0.03
# 25        Missouri                    0.03                    0.04
# ...

# %% [markdown]
# The number of states that have a participation rate of more than 50% on the ACTs is slightly higher than that of that states that have a participation of more than 50% on the SATs.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#Seaborn Heatmap
fig = plt.figure(figsize=(12,12))
ax = sns.heatmap(final_updated.corr(),annot=True,cmap="RdBu", center=0)
ax.set_title('Correlation Heatmap for SAT and ACT Data\n');
plt.tight_layout()

# %% [markdown]
# The scores of tests on the individual components are negatively correlated with the participation rate on that test. The lower participation rates, resulted in a higher mean test scores and higher participation rates resulting in lower mean test scores. This would indicate a selection bias, whereby only higher achieving students took part in the test.
#
# The average scores of the individual components of a given test is highly correlated with average scores of the other individual components as well as the average total score. This is also seen for both 2017 and 2018.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        plt.tight_layout()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
#Participation rates for SAT & ACT
subplot_histograms(final_updated,['sat_2017_participation',
                                  'act_2017_participation',
                                  'sat_2018_participation',
                                  'act_2018_updated_participation'],
                   ['Participation SAT 2017',
                    'Participation ACT 2017',
                    'Participation SAT 2018',
                    'Participation ACT (updated) 2018'],
                   ['Mean Participation',
                    'Mean Participation',
                    'Mean Participation',
                    'Mean Participation'])

# %% [markdown]
# There is a higher participation rate for the ACTs as compared to the participation of the SATs.

# %%
#Math scores for SAT & ACT
subplot_histograms(final_updated,['sat_2017_math',
                                  'act_2017_math', 
                                  'act_2018_updated_math'],
                   ['Mean SAT Math 2017',
                    'Mean ACT Math 2017',
                    'Mean ACT Math 2018'],
                   ['Mean Score',
                    'Mean Score',
                    'Mean Score'])

# %% [markdown]
# Participants taking part in the test seemed to perform better for the SAT math test as compared to the ACTs. There seemed to be a shift towards slightly higher scores in the mean ACT math socres from 2017 to 2018.

# %%
#Reading/verbal scores for SAT & ACT
subplot_histograms(final_updated,['sat_2017_ewb',
                          'sat_2018_ewb',
                          'act_2017_reading',
                          'act_2018_updated_reading'],
                   ['Mean SAT EWB 2017',
                    'Mean SAT EWB 2018',
                    'Mean ACT Reading 2017', 
                    'Mean ACT Reading (updated) 2018'],
                   ['Mean Score',
                    'Mean Score',
                    'Mean Score',
                    'Mean Score'])

# %% [markdown]
# Slight increase in the mean reading scores over the years.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#Defines a function to create a scatterplot between two variables
def subplot_scatterplot(column1,column2,xlabel,ylabel,title):
    f = plt.figure(figsize=(8,5))
    sns.set_style('whitegrid')
    sns.scatterplot(x=final_updated[column1],y=final_updated[column2])
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title);
    plt.tight_layout()

# %%
# Code
#SAT vs. ACT math scores for 2017
subplot_scatterplot('sat_2017_math',
                    'act_2017_math',
                    'SAT 2017 Math',
                    'ACT 2017 Math',
                    'SAT vs. ACT math scores for 2017')

# %%
#SAT vs. ACT verbal/reading scores for 2017
subplot_scatterplot('sat_2017_ewb',
                    'act_2017_reading',
                    'SAT 2017 EWB',
                    'ACT 2017 Reading',
                    'SAT vs. ACT Reading scores for 2017')

# %% [markdown]
# There is little or no correlation between SAT and ACT verbal/reading scores for 2017.

# %%
#SAT vs. ACT total/composite scores for 2017
subplot_scatterplot('act_2017_comp',
                    'sat_2017_total',
                    'ACT 2017 Composite Score',
                    'SAT 2017 Total Score',
                    'SAT vs. ACT total/composite scores for 2017')

# %% [markdown]
# There is little or no correlation between SAT and ACT total/composite scores for 2017.

# %%
#Total scores for SAT 2017 vs. 2018
subplot_scatterplot('sat_2017_total',
                    'sat_2018_total',
                    'SAT 2017 Total Score',
                    'SAT 2018 Total Score',
                    'Total scores for SAT 2017 vs. 2018')

# %% [markdown]
# There is a positive correlation between the SAT scores of 2017 and 2018. There are a few exceptions where the mean total score dropped from 2017 to 2018.

# %%
#Composite scores for ACT 2017 vs. 2018
subplot_scatterplot('act_2017_comp',
                    'act_2018_updated_comp',                   
                    'ACT 2017 Composite Score',
                    'ACT 2018 Composite (updated) Score',
                    'Composite scores for ACT 2017 vs. 2018')

# %% [markdown]
# There is a positive correlation between the ACT scores of 2017 and 2018.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
#Boxplot for ACT and SAT participation rates, 2017 and 2018 (4 vars)
participation_rates = final_updated.loc[:,['sat_2017_participation',
                                   'sat_2018_participation',
                                   'act_2017_participation',
                                   'act_2018_updated_participation']]

plt.figure(figsize=(10,6))
plt.title('Distribution of ACT and SAT Participation Rates')
sns.boxplot(data=participation_rates,orient='h',palette='Set3');
plt.tight_layout()

# %% [markdown]
# Overall, ACT has a higher participation rate compared to the SATs.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
subplot_scatterplot('sat_2017_participation',
                    'sat_2017_total',                   
                    'SAT 2017 Participation',
                    'SAT 2017 Total',
                    'SAT 2017 Participation vs. SAT 2017 Total Scores')

# %% [markdown]
# There is a negative relationship between participation and total scores in 2017.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final_stats = final_updated.describe().T

# %%
final_stats=final_stats[[ 'std', 'min', '25%', '50%', 'mean', '75%', 'max', 'count']]
final_stats
# Out:
#                                       std     min       25%      50%  \
# act_2017_participation           0.321408    0.08     0.310     0.69
# act_2017_english                 2.353677   16.30    19.000    20.70
# act_2017_math                    1.981989   18.00    19.400    20.90
# act_2017_reading                 2.067271   18.10    20.450    21.80
# act_2017_science                 1.739353   18.20    19.950    21.30
# act_2017_comp                    2.020695   17.80    19.800    21.40
# sat_2017_participation           0.352766    0.02     0.040     0.38
# sat_2017_ewb                    45.666901  482.00   533.500   559.00
# sat_2017_math                   47.121395  468.00   523.500   548.00
# sat_2017_total                  92.494812  950.00  1055.500  1107.00
# act_2018_updated_participation   0.340810    0.07     0.285     0.66
# act_2018_updated_comp            2.106278   17.70    19.950    21.30
# act_2018_updated_english         2.446356   16.60    19.100    20.20
# ...

# %%
subplot_histograms(final_updated,['sat_2017_ewb',
                                  'sat_2018_ewb',
                                  'sat_2017_total', 
                                  'sat_2018_total',
                                  'sat_2018_math'],
                   ['Mean SAT EWB 2017',
                    'Mean SAT EWB 2018',
                    'Mean SAT Total 2017', 
                    'Mean SAT Total 2018', 
                    'Mean SAT Math 2018'],
                   ['Mean Score',
                    'Mean Score',
                    'Mean Score',
                    'Mean Score', 
                    'Mean Score'])

# %%
#Participation rates for SAT & ACT
subplot_histograms(final_updated,['act_2017_participation',
                                  'act_2018_updated_participation',
                                  'sat_2017_participation',
                                  'sat_2018_participation'],
                   ['Participation ACT 2017',
                    'Participation ACT 2018 (updated)',
                    'Participation SAT 2017',
                    'Participation SAT 2018'],
                   ['Mean Participation',
                    'Mean Participation',
                    'Mean Participation',
                    'Mean Participation'])

# %% [markdown]
# | data|std|min|25%|50%|mean|75%|max|count|
# |---|---|---|---|---|---|---|---|---|
# |act_2017_participation|0.321408|0.08|0.310|0.69|0.652549|1.000|1.0|51.0|
# |act_2018_participation|0.340810|0.07|0.285|0.66|0.616471|1.000|1.0|51.0|
# |sat_2017_participation|0.352766|0.02|0.040|0.38|0.398039|0.660|1.0|51.0|
# |sat_2018_participation|0.373143|0.02|0.045|0.52|0.457451|0.775|1.0|51.0|

# %%
final_updated.kurtosis()
# Out:
# act_2017_participation           -1.631970
# act_2017_english                 -0.879307
# act_2017_math                    -0.979210
# act_2017_reading                 -0.982094
# act_2017_science                 -0.956033
# act_2017_comp                    -0.983524
# sat_2017_participation           -1.380695
# sat_2017_ewb                     -1.220371
# sat_2017_math                    -0.925843
# sat_2017_total                   -1.105461
# act_2018_updated_participation   -1.738681
# act_2018_updated_comp            -1.080666
# act_2018_updated_english         -1.071710
# act_2018_updated_math            -1.109059
# act_2018_updated_reading         -1.116031
# act_2018_updated_science         -1.109301
# sat_2018_participation           -1.569003
# sat_2018_ewb                     -1.055118
# sat_2018_math                    -0.756126
# sat_2018_total                   -1.022725
# dtype: float64

# %%
final_updated.skew()
# Out:
# act_2017_participation           -0.197989
# act_2017_english                  0.352660
# act_2017_math                     0.332683
# act_2017_reading                  0.269366
# act_2017_science                  0.218823
# act_2017_comp                     0.319810
# sat_2017_participation            0.346450
# sat_2017_ewb                      0.272693
# sat_2017_math                     0.365040
# sat_2017_total                    0.310903
# act_2018_updated_participation   -0.021916
# act_2018_updated_comp             0.281962
# act_2018_updated_english          0.371507
# act_2018_updated_math             0.269548
# act_2018_updated_reading          0.201361
# act_2018_updated_science          0.172383
# sat_2018_participation            0.136228
# sat_2018_ewb                      0.282300
# sat_2018_math                     0.530407
# sat_2018_total                    0.466432
# dtype: float64

# %% [markdown]
# The mean of positively skewed data will be greater than the median. In a distribution that is negatively skewed, the exact opposite is the case: the mean of negatively skewed data will be less than the median.
#
# From the table, I have picked out data where the mean is significantly greater (mean-median>10) than the median. This is true for SAT 2017 EWB, SAT 2018 EWB, SAT 2017 Total, SAT 2018 Total, and SAT 2018 Math.
#
# As seen from the table and graphs above, we can observe that most of the data are on the left and the data is seen to be skewed to the right. Thus, it is indicative that the skewness of the graph and distributions are positively-skewed.
#
# In the summarise table for the participation for the ACTs and SATs in 2017 and 2018, there has been as increase in the mean participation of students from 0.398 to 0.457. A slight decrease can be observed for the ACT participation rate. The standard deviation for the participation rate ranges from 0.3 to 0.4. This indicates that the participation rates tend to be relatively close to the mean.
#
# The skewness for a normal distribution is zero, and any symmetric data should have a skewness near zero. All variables do not have a skewness = 0 thus they are not normally distributed. Negative values for the skewness indicate data that are skewed left and positive values for the skewness indicate data that are skewed right. The ACT participation for 2017 and 2018 are left skewed with a longer left tail in comparision to the right, which can also be seen in the figure above. Similarly, skewed right means that the right tail is long relative to the left tail. The rest of the variables have positive values and thus have a longer left tail.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# For normal distribution to be observed, the data should be around the central value with no left or right bias.
#
# As observed from above calculated skewness and kurtosis, the data given do not follow the normal distribution.
#
# Seemingly, for the participation rates, places whereby the participation is high, the test scores are lower and results in a dilution for the quality of performance. This is true for the opposite where lower participation results in higher performance score. This could be indication of a selection bias, whereby the more academically inclined students form the larger population that is taking the tests.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# The data given does not include the total population size and thus the size of the sample is unknown. Instead, we are provided with an average of the data/scores of each individual state.
# There is insufficient data discrimination, and thus an insufficient data discrimination of different values, since only the average values were given. These values result in more extreme values, leading to a skewed distribution.
#
# In the instances where participation rate are low and test scores are high, that could be indicate biasness towards the more academically inclined students only and thus pushing up the state's tests score.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# No. From the histogram, there seem to be groups of states with high mean math scores and groups of low mean math state scores, which results from the low and high participation from states respectively. Thus, is it not indicative of the performance of the state, but rather only a handful of individuals.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
participation[(participation.sat_2017_participation <= 0.50) 
              & (participation.act_2017_participation <= 0.50)]
# Out:
#      state  sat_2017_participation  sat_2018_participation  \
# 37  Oregon                    0.43                    0.48
#
#     act_2017_participation  act_2018_updated_participation
# 37                     0.4                            0.42

# %%
participation[(participation.sat_2018_participation <= 0.50) 
              & (participation.act_2018_updated_participation <= 0.50)]
# Out:
#      state  sat_2017_participation  sat_2018_participation  \
# 1   Alaska                    0.38                    0.43
# 37  Oregon                    0.43                    0.48
#
#     act_2017_participation  act_2018_updated_participation
# 1                     0.65                            0.33
# 37                    0.40                            0.42

# %% [markdown]
# Colorado and Illinois started with a higher participation rate for the ACT tests in 2017, but subsequently changed to have a 100% participation for the SATs in 2018.
# From further research, Colorado and the College Board partnered to administer the SAT as the state's accountability exam. This explains the increase in participation rates for the SAT in 2018. Similarly, there was a transition from ACT to SAT as the Illinois College Entrance Exam. In previous years, the exam mandated by the state of Illinois was the ACT. The major reason for the switch is due to the change of the composition of its mathematics curriculum.
#
# Oregon has a low participation rate >50% participation for both the SATs and ACTs. From research, it is seen that Oregon schools rank in the bottom third nationally and the state has a weak financial contribution to schools. The low participation rate of Oregon might also be due to growing disparity among the rich and the poor, thus people are less able afford education.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Overall, the ACT and SAT participation distributions were similar. In instances where the particpation of a particular test was higher, it would result in a lower percentage of participation in the other. The ACTs had a higher baseline participation percentage, and seemed to be the more popular choice among the states. However, there seemed to be a slow change over to the SATS, with states like Colorado and Illinois making a switch over to the SATs from the ACTs.
#
# Being a non-profit organisation with the goal to increase the overall participation for the SAT to provide an entrance to college, I would suggest for the college board to first target Oregon. Oregon has the lowest participation rate among the states for both the ACT and SAT test. This is due to the lack of funding for their education system and growing income disparity among the people. There is an opportunity for the College Board to come in and promote the SAT with intentions to help students achieve higher education access. The College Board can consider working with the schools in Oregon rolling out the SAT School Day programme to provide the option for a subsidised fee for the SAT. I believe that this might help change the mindset and priority placed on education to help increase the overall participation in the SAT test as well as to open up opportunities for further education. Achieving an improve SAT participation for Oregon and a greater emphasis for continued learning in Oregon will be the best way to spend resources.

# %%
participation
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 0                Alabama                    0.05                    0.06
# 1                 Alaska                    0.38                    0.43
# 2                Arizona                    0.30                    0.29
# 3               Arkansas                    0.03                    0.05
# 4             California                    0.53                    0.60
# 5               Colorado                    0.11                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 8   District of Columbia                    1.00                    0.92
# 9                Florida                    0.83                    0.56
# 10               Georgia                    0.61                    0.70
# 11                Hawaii                    0.55                    0.56
# ...
