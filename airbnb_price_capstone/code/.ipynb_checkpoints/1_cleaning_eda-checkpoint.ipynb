# %% [markdown]
# # Capstone: Airbnb Price Predictions (Singapore)
#
# ## Problem Statement
#
# I will build a regression model to predict the listing price of houses to be listed on Airbnb. Model performance will be guided by RMSE, and the model should at least imporve upon baseline by 10%. Baseline is defined as the average daily costs per night for a housing listing in Singapore.
#
# ## Executive Summary
#
# This Jupyter notebook walks through the price prediction for potential Airbnb hosts.
#
# Airbnb provides easy access for users looking for a apartment rentals in Singapore, with information provided by the hosts on the platform. However, it might not be as convenient for potential listers. One challenge that Airbnb hosts might face is in determining an optimal rent price to rent out their spaces.
#
# ---
# ### Contents:
# - [Data Import & Cleaning](#Data-Import-&-Cleaning)
#     + [Data Cleaning: Initial Check](#Data-Cleaning:-Initial-Check)
#     + [Data Cleaning: Dropping Initial Columns](#Data-Cleaning:-Dropping-Initial-Columns)
#     + [Data cleaning: Null Values](#Data-cleaning:-Null-Values)
#     + [Data Cleaning: According to Type](#Data-Cleaning:-According-to-Type)
# - [Exploratory Data Analysis](#EDA)
#     + [Distribution of Target Value - Price](#Distribution-of-Target-Value---Price)
#     + [Categorical Features](#Categorical-Features)
#     + [Numerical Features](#Numerical-Features)
# ---

# %%
# imports:

#maths
import pandas as pd
import numpy as np
import scipy.stats as stats
from datetime import datetime

#visual
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
##!pip3 install geopandas
import geopandas as gpd
##!pip3 install descartes

# %matplotlib inline

#To visualize the whole grid
pd.options.display.max_columns = 999

plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Import & Cleaning
#
# #### Read Airbnb Singapore datasets
#
# Load in the `listing.csv` files and assign it to an appropriately named pandas dataframes.

# %%
airbnb_data = pd.read_csv('../data/listings.csv')

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(20), int64(23), object(63)
# memory usage: 6.5+ MB

# %%
airbnb_data.drop_duplicates(subset = 'name', inplace = True)

# %%
# display all cols of airbnb data
airbnb_cols = airbnb_data.columns.tolist()

# display the first 10 columns
airbnb_cols[:10]
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview']

# %% [markdown]
# #### Display Data

# %%
airbnb_data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  49091  https://www.airbnb.com/rooms/49091  20200227171146   2020-02-28
# 1  50646  https://www.airbnb.com/rooms/50646  20200227171146   2020-02-27
# 2  56334  https://www.airbnb.com/rooms/56334  20200227171146   2020-02-28
# 3  71609  https://www.airbnb.com/rooms/71609  20200227171146   2020-02-28
# 4  71896  https://www.airbnb.com/rooms/71896  20200227171146   2020-02-28
#
#                                   name  \
# 0    COZICOMFORT LONG TERM STAY ROOM 2
# 1      Pleasant Room along Bukit Timah
# 2                          COZICOMFORT
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
#
#                                              summary  \
# 0                                                NaN
# 1  Fully furnished bedroom with a nice view on th...
# 2                                                NaN
# 3  For 3 (Website hidden by Airbnb) room 1&2 and ...
# 4                                                NaN
#
#                                                space  \
# 0  This is Room No. 2.(available after Jan 15 201...
# 1  Good Condition room, bright & windy. Comes wit...
# 2  This is Room no. 1. USD700 per month On the fa...
# 3  Landed Homestay Room for Rental. Between Simei...
# 4  Vocational Stay Deluxe Bedroom in Singapore.(N...
#
#                                          description experiences_offered  \
# 0  This is Room No. 2.(available after Jan 15 201...                none
# 1  Fully furnished bedroom with a nice view on th...                none
# 2  This is Room no. 1. USD700 per month On the fa...                none
# 3  For 3 (Website hidden by Airbnb) room 1&2 and ...                none
# 4  Vocational Stay Deluxe Bedroom in Singapore.(N...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The serenity & quiet surrounding makes it an i...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  Accommodation has a queen size bed.  Suitable ...
# 2                                                NaN
# 3  Incase there is some changes in the rooms allo...
# 4  Incase there is some changes in the rooms allo...
#
#                                              transit  \
# 0                                                NaN
# 1  Less than 400m from the apartment is the main ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               access  \
# 0                                                NaN
# 1  Kitchen, washing facilities, gym, swimming poo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          interaction  \
# 0                                                NaN
# 1  We love to host people & have the opportunity ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  No smoking indoors. Please turn off lights/fan...            NaN
# 1  '- Should be family friendly. '- Cooking is no...            NaN
# 2  No smoking indoors. Please turn off lights/air...            NaN
# 3  Home Stay Rules  House Rules & Check in Requir...            NaN
# 4  Vocational Stay Rules  - Do not excessively me...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/24485541/6...
# 1         NaN  https://a0.muscache.com/im/pictures/36342984/6...
# 2         NaN  https://a0.muscache.com/im/pictures/20783922/1...
# 3         NaN  https://a0.muscache.com/im/pictures/24453191/3...
# 4         NaN  https://a0.muscache.com/im/pictures/2440674/ac...
#
#    xl_picture_url  host_id                                  host_url  \
# 0             NaN   266763  https://www.airbnb.com/users/show/266763
# 1             NaN   227796  https://www.airbnb.com/users/show/227796
# 2             NaN   266763  https://www.airbnb.com/users/show/266763
# 3             NaN   367042  https://www.airbnb.com/users/show/367042
# 4             NaN   367042  https://www.airbnb.com/users/show/367042
#
#    host_name  host_since         host_location  \
# 0  Francesca  2010-10-20             singapore
# 1    Sujatha  2010-09-08  Singapore, Singapore
# 2  Francesca  2010-10-20             singapore
# 3    Belinda  2011-01-29             Singapore
# 4    Belinda  2011-01-29             Singapore
#
#                                           host_about host_response_time  \
# 0  I am a private tutor by profession. My husband...       within a day
# 1  I am a working professional, living in Singapo...       within a day
# 2  I am a private tutor by profession. My husband...       within a day
# 3  Hi My name is Belinda -Housekeeper \r\n\r\nI w...     within an hour
# 4  Hi My name is Belinda -Housekeeper \r\n\r\nI w...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  NaN                 f
# 1               100%                  NaN                 f
# 2               100%                  NaN                 f
# 3               100%                 100%                 f
# 4               100%                 100%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/c9b1c...
# 1  https://a0.muscache.com/im/pictures/user/8fd2c...
# 2  https://a0.muscache.com/im/pictures/user/c9b1c...
# 3  https://a0.muscache.com/im/users/367042/profil...
# 4  https://a0.muscache.com/im/users/367042/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/c9b1c...          Woodlands
# 1  https://a0.muscache.com/im/pictures/user/8fd2c...        Bukit Timah
# 2  https://a0.muscache.com/im/pictures/user/c9b1c...          Woodlands
# 3  https://a0.muscache.com/im/users/367042/profil...           Tampines
# 4  https://a0.muscache.com/im/users/367042/profil...           Tampines
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          2
# 1                    1                          1
# 2                    2                          2
# 3                    8                          8
# 4                    8                          8
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 1  ['email', 'phone', 'facebook', 'reviews', 'off...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 3  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 4  ['email', 'phone', 'reviews', 'manual_offline'...                    t
#
#   host_identity_verified                street neighbourhood  \
# 0                      f  Singapore, Singapore     Woodlands
# 1                      f  Singapore, Singapore   Bukit Timah
# 2                      f  Singapore, Singapore     Woodlands
# 3                      t  Singapore, Singapore      Tampines
# 4                      t  Singapore, Singapore      Tampines
#
#   neighbourhood_cleansed neighbourhood_group_cleansed       city state  \
# 0              Woodlands                 North Region  Singapore   NaN
# 1            Bukit Timah               Central Region  Singapore   NaN
# 2              Woodlands                 North Region  Singapore   NaN
# 3               Tampines                  East Region  Singapore   NaN
# 4               Tampines                  East Region  Singapore   NaN
#
#   zipcode     market smart_location country_code    country  latitude  \
# 0  730702  Singapore      Singapore           SG  Singapore   1.44255
# 1  589664  Singapore      Singapore           SG  Singapore   1.33235
# 2     NaN  Singapore      Singapore           SG  Singapore   1.44246
# 3  488405  Singapore      Singapore           SG  Singapore   1.34541
# 4  488405  Singapore      Singapore           SG  Singapore   1.34567
#
#    longitude is_location_exact property_type     room_type  accommodates  \
# 0  103.79580                 t     Apartment  Private room             1
# 1  103.78521                 t     Apartment  Private room             2
# 2  103.79667                 t     Apartment  Private room             1
# 3  103.95712                 t         Villa  Private room             6
# 4  103.95963                 t         House  Private room             3
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.0       1.0   1.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
# 3        1.0       2.0   3.0  Real Bed
# 4        0.5       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          0.0   $84.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   $80.00
# 2  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          0.0   $70.00
# 3  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...        205.0  $207.00
# 4  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $95.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN     $1,047.00              NaN          NaN                1
# 1      $400.00     $1,600.00              NaN          NaN                2
# 2          NaN       $977.00              NaN          NaN                1
# 3          NaN     $5,582.00          $279.00       $56.00                4
# 4      $698.00     $2,512.00          $140.00       $28.00                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $14.00             180             360                     180
# 1       $20.00              90             730                      90
# 2       $14.00               6              14                       6
# 3       $28.00               1            1125                       1
# 4       $21.00               1            1125                       1
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                     180                     360                     360
# 1                      90                     730                     730
# 2                       6                      14                      14
# 3                       1                    1125                    1125
# 4                       1                    1125                    1125
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                   180.0                   360.0    69 months ago
# 1                    90.0                   730.0    67 months ago
# 2                     6.0                    14.0    64 months ago
# 3                     1.0                  1125.0      2 weeks ago
# 4                     1.0                  1125.0      2 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               30               60               90
# 1                t               30               60               90
# 2                t               30               60               90
# 3                t               30               60               90
# 4                t               30               60               90
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               365            2020-02-28                  1
# 1               365            2020-02-27                 18
# 2               365            2020-02-28                 20
# 3               365            2020-02-28                 20
# 4               365            2020-02-28                 24
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2013-10-21  2013-10-21                  94.0
# 1                      0   2014-04-18  2014-12-26                  91.0
# 2                      0   2011-06-25  2015-10-01                  98.0
# 3                      8   2011-12-19  2020-01-17                  89.0
# 4                      4   2011-07-30  2019-10-13                  83.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     9.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                     9.0                        8.0                    9.0
# 4                     8.0                        8.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     8.0                  8.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     8.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                          9.0                     8.0                  8.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                f     NaN                 NaN                f
# 1                f     NaN                 NaN                f
# 2                f     NaN                 NaN                f
# 3                f     NaN                 NaN                t
# 4                f     NaN                 NaN                t
#
#   is_business_travel_ready cancellation_policy require_guest_profile_picture  \
# 0                        f            flexible                             t
# 1                        f            moderate                             f
# 2                        f            flexible                             t
# 3                        f            flexible                             f
# 4                        f            moderate                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                t                               2
# 1                                t                               1
# 2                                t                               2
# 3                                t                               8
# 4                                t                               8
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             1
# 2                                             2
# 3                                             8
# 4                                             8
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               0.25
# 2                                            0               0.19
# 3                                            0               0.20
# 4                                            0               0.23

# %% [markdown]
# ### Data Cleaning: Initial Check
#
# Check the following in the cells below:
# 1. Do we have any null values?
# 2. Are any numerical columns being read wrongly?
# 3. Remove columns that are not neccesary for price prediction

# %%
# date that this particular data was scraped

airbnb_data.last_scraped.unique()
# Out:
# array(['2020-02-28', '2020-02-27'], dtype=object)

# %%
null_values = airbnb_data.isnull().sum().sort_values(ascending=False)

# %%
null_values_df = pd.DataFrame(data=null_values, columns=['no.'])

# %%
null_values_df.head(5)
# Out:
#                      no.
# jurisdiction_names  7429
# xl_picture_url      7429
# medium_url          7429
# thumbnail_url       7429
# license             7423

# %% [markdown]
# ### Data Cleaning: Dropping Initial Columns

# %% [markdown]
# #### Availability
# In Singapore, the minimum stay duration of three months applies for any accommodation in private residential properties. Therefore, I will only retain the availability for 90 days and drop the rest.

# %%
# dropping at availability

airbnb_data.drop(['availability_30',
                  'availability_60',
                  'availability_365'],
              axis = 1, 
              inplace = True)

# %% [markdown]
# #### Host Listings
#
# The `calculated_host_listings_` are columns that have been split into the different types of properties, thus I will drop them as they will be highly correlated.

# %%
host_listings = ['calculated_host_listings_count_entire_homes',
                 'calculated_host_listings_count_private_rooms',
                 'calculated_host_listings_count_shared_rooms']
airbnb_data[host_listings].describe()
# Out:
#        calculated_host_listings_count_entire_homes  \
# count                                  7429.000000
# mean                                     26.163279
# std                                      57.439736
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                      24.000000
# max                                     335.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7429.000000
# mean                                       8.383901
# std                                       22.618125
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        4.000000
# max                                      128.000000
#
#        calculated_host_listings_count_shared_rooms
# count                                  7429.000000
# mean                                      0.388881
# std                                       2.016141
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                      20.000000

# %%
# looking at individual columns: host_listings_count, host_total_listings_count, calculated_host_listings_count

print(sum((airbnb_data.host_listings_count == airbnb_data.host_total_listings_count) == False))
print(sum((airbnb_data.host_listings_count == airbnb_data.calculated_host_listings_count) == False))

# all columns tally so I will drop host_total_listings_count
# Out:
# 0
# 3959

# %%
# looking at the diff in columns between host_listings_count and calculated_host_listings_count

airbnb_data_listing = airbnb_data.loc[((airbnb_data.host_listings_count == airbnb_data.calculated_host_listings_count) == False)]
cols = ['host_listings_count','calculated_host_listings_count']
airbnb_data_listing[cols].head()

# seems like the columns differ by a bit, so I will be keeping the original
# host_listing_count
# Out:
#     host_listings_count  calculated_host_listings_count
# 23                    2                               1
# 30                    2                               1
# 32                    6                               4
# 38                  126                             128
# 49                  126                             128

# %%
# drop host_listings

airbnb_data.drop(host_listings, axis=1, inplace = True)

# %% [markdown]
# #### Reviews/URLS
# Dropping all columns that contain the word `review` since the inital prediction of prices would not inlcude any reviews yet. In creation of this initial model, I will not be using NLP. NLP can be used subsequently for sentimental analysis for further predictions if needed. As such, I will be dropping text based features such as `listing_url`, etc.

# %%
# removing all columns that consist of reviews

airbnb_data = airbnb_data[airbnb_data.columns.drop(list(airbnb_data.filter(regex='review')))]

# %%
# removing all columns that contains url

airbnb_data = airbnb_data[airbnb_data.columns.drop(list(airbnb_data.filter(regex='url')))]

# %%
airbnb_cols = airbnb_data.columns.tolist()
airbnb_cols[:10]
# Out:
# ['id',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes']

# %% [markdown]
# #### Minimum/Maximum Nights
#
# Looking at all the minimum and maximum columns, to figure out which we should keep.

# %%
# looking at minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights,
# minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm

print(sum((airbnb_data.minimum_nights == airbnb_data.minimum_minimum_nights) == False))
print(sum((airbnb_data.minimum_nights == airbnb_data.maximum_minimum_nights) == False))
print(sum((airbnb_data.minimum_nights == airbnb_data.minimum_nights_avg_ntm) == False))

print(sum((airbnb_data.maximum_nights == airbnb_data.maximum_maximum_nights) == False))
print(sum((airbnb_data.maximum_nights == airbnb_data.minimum_maximum_nights) == False))
print(sum((airbnb_data.maximum_nights == airbnb_data.maximum_nights_avg_ntm) == False))

# there is minor diff between the minimum amd maximum and the rest so i will just keep 
# the original and drop the rest
# Out:
# 470
# 276
# 440
# 544
# 556
# 564

# %% [markdown]
# #### Neighbourhood/Location
#
# Looking at all the columns that include the neighbourhoods.

# %%
# looking at neighbourhood and neighbourhood_cleansed

print(sum((airbnb_data.neighbourhood == airbnb_data.neighbourhood_cleansed) == False))
# Out:
# 2499

# %%
print(airbnb_data['neighbourhood_cleansed'].isnull().sum())
print(airbnb_data['neighbourhood'].isnull().sum())

# neighbourhood_cleansed is the clean neighbourhood and since neighbourhood 
# has null values, I will drop that and used neighbourhood_cleansed instead
# Out:
# 0
# 3

# %%
# looking at smart_location

airbnb_data.smart_location.unique()

# contain random locations, not consistent
# Out:
# array(['Singapore', 'Sembawang, Singapore', 'Opera Estate, Singapore',
#        'Changi, Singapore', 'Singapour, Singapore', 'Kallang , Singapore',
#        'Singapore , Singapore', 'Whampoa, Singapore', 'SG, Singapore',
#        'Novena, Singapore', 'Punggol, Singapore', 'Bedok, Singapore',
#        'SINGAPORE, Singapore', 'singapore, Singapore',
#        'Woodlands, Singapore', '#04-354, Singapore',
#        'The Shore Residences, Singapore', '实龙岗, Singapore',
#        'Serangoon, Singapore', '兀兰, Singapore', '武吉巴督, Singapore',
#        'Pasir Ris Grove, Singapore', 'Geylang  East, Singapore',
#        'Pasir Panjang Hill, Singapore', 'Holland Village, Singapore',
#        'Singpapore , Singapore', 'Sengkang, Singapore',
#        'Novena , Singapore', 'Singapore, SG, Singapore',
#        'bedok, Singapore', 'Woodlands , Singapore',
#        'Mountbatten, Singapore', 'Geylang, Singapore', '新加坡, Singapore',
#        'Little India, Singapore', '67 Sophia road, Singapore',
#        'Singapura, Singapore', 'Tanjong Pagar, Singapore',
#        'Jurong, Singapore', 'Lavender, Singapore', 'n/a, Singapore',
#        '*, Singapore', 'Tampines, Singapore', 'City, Singapore',
#        'Bukit Timah, Singapore', ' Farrer Park, Singapore',
#        'Farrer Park, Singapore', '淡滨尼, Singapore'], dtype=object)

# %%
# looking at street

airbnb_data.street.unique()

# contain mostly 'Singapore', thus will not be useful since we are already predicting for Singapore
# Out:
# array(['Singapore, Singapore', 'Singapore, Singapore, Singapore',
#        'Sembawang, Sembawang, Singapore',
#        'Opera Estate, Bedok / Kembangan / Siglap, Singapore',
#        'Changi, Singapore, Singapore', 'Singapore, Chinatown, Singapore',
#        'Singapore, Ipoh, Singapore', 'Singapour, Singapore',
#        'Singapore, singapore, Singapore',
#        'Singapore, Chinatown, Outram, Singapore',
#        'Kallang , Singapore, Singapore',
#        'Singapore , Balastier, Singapore',
#        'Whampoa, Singapore, Singapore', 'Singapore, Malacca, Singapore',
#        'Singapore, Choa Chu Kang, Singapore',
#        'Singapour, Singapour, Singapore',
#        'Singapore, Farrer Park Station, Singapore',
#        'Singapore, Sg, Singapore', 'SG, Singapore',
#        'Singapore, Singpaore, Singapore', 'Novena, Singapore, Singapore',
#        'Singapore, Punggol, Singapore',
#        'Singapore , Singapore, Singapore',
#        'Singapore, Singapòre, Singapore',
#        'Singapore, Please select region, state or province, Singapore',
#        'Punggol, Singapore, Singapore',
#        'Singapore, Bukit Timah, Singapore',
#        'Singapore, 207557, Singapore', 'Bedok, Singapore, Singapore',
#        'Singapore, Katong, Singapore', 'SINGAPORE, SINGAPORE, Singapore',
#        'Bedok, Singapore', 'singapore, singapore, Singapore',
#        'Woodlands, Singapore', 'Singapore, 640861, Singapore',
#        '#04-354, Singapore', 'Singapore, Balestier, Singapore',
#        'Singapore, NA, Singapore', 'Singapore, Novena, Singapore',
#        'The Shore Residences, Singapore, Singapore',
#        'Singapore, Sembawang Spring Estate, Singapore',
#        'Singapore, SINGAPORE, Singapore', '实龙岗, 新加坡, Singapore',
#        'Singapore, SG, Singapore', 'Serangoon, Singapore, Singapore',
#        'Singapore, Jalan Eunos, Singapore', 'Singapore, 新加坡, Singapore',
#        '兀兰, 新加坡, Singapore', '武吉巴督, 新加坡, Singapore',
#        'Pasir Ris Grove, grove, Singapore',
#        'Singapore, Beijing, Singapore', 'Singapore, 0, Singapore',
#        'Singapore, Kovan, Singapore',
#        'Geylang  East, Singapore, Singapore', 'Singapore, -, Singapore',
#        'Singapore, S, Singapore', 'Singapore, Kim keat, Singapore',
#        'Pasir Panjang Hill, Singapore, Singapore',
#        'Holland Village, Singapore, Singapore',
#        'Singapore, Pasir Ris, Singapore',
#        'Singpapore , Singapore, Singapore',
#        'Singapore, Singpore, Singapore', 'Sengkang, Singapore, Singapore',
#        'Singapore, singappre, Singapore',
#        'Singapore, Singaporean, Singapore',
#        'Novena , Singapore, Singapore', 'Singapore, Ave2, Singapore',
#        'Singapore, ge\u2006y\u2006lang, Singapore',
#        'Singapore, SG, SINGAPORE, Singapore',
#        'bedok, singapore, Singapore', 'Woodlands , Singapore, Singapore',
#        'Mountbatten, Singapore, Singapore', 'Geylang, 新加坡, Singapore',
#        '新加坡, Koven, Singapore', 'Singapore, boon keng, Singapore',
#        'Singapore, VIC, Singapore', 'Singapore , Singapore',
#        'Little India, Singapore, Singapore', 'Singapore, Link, Singapore',
#        '67 Sophia road, Singapore', 'Singapura, Singapore',
#        'Tanjong Pagar, Singapore, Singapore',
#        'Jurong, Singapore, Singapore', 'Lavender, SIN, Singapore',
#        'n/a, n/a, Singapore', 'Singapore, *, Singapore',
#        'Singapore, Johor, Singapore', '*, Singapore, Singapore',
#        'Tampines, Singapore, Singapore', 'singapore, Singapore',
#        '新加坡, Singapore', 'Singapore, Seoul, Singapore', 'City, Singapore',
#        'Singapore , 新加坡, Singapore', 'Bukit Timah, Singapore, Singapore',
#        ' Farrer Park, Singapore', 'Farrer Park, Singapore',
#        'Singapore, Uttar Pradesh, Singapore',
#        'Singapore, Guangdong, Singapore', '淡滨尼, 新加坡, Singapore'],
#       dtype=object)

# %% [markdown]
# #### Removing Irrelevant Columns

# %%
# remove columns that are descriptive/irrelevant

drop_col = ['last_scraped',                        #drop cause not necessary just show dates
           'summary',                              #drop cause description
           'name',                                 #drop cause description
           'transit',                              #drop cause transit is decriptive and can be derived from neighborhood
           'space',                                #drop cause description
           'description',                          #drop cause description
           'experiences_offered',                  #drop cause all null
           'neighborhood_overview',                #drop cause description
           'notes',                                #drop cause description
           'access',                               #drop cause description
           'interaction',                          #drop cause descriptive and not needed in inital prediction
           'house_rules',                          #drop cause description
           'host_id',                              #drop cause not necessary
           'host_name',                            #drop cause not necessary
           'host_about',                           #drop cause not necessary
           'host_total_listings_count',            #drop cause repeated
           'city',                                 #drop cause this is limited to SG
           'state',                                #drop cause inconsistent and should all be SG
           'country_code',                         #drop cause all the same
           'country',                              #drop cause all the same
           'minimum_minimum_nights',               #drop cause repeated
           'maximum_minimum_nights',
           'minimum_maximum_nights',
           'maximum_maximum_nights',
           'minimum_nights_avg_ntm',
           'maximum_nights_avg_ntm',
           'calendar_last_scraped',                #drop because it just indicates last scraped
           'jurisdiction_names',                   #drop not needed/all nulls
           'is_business_travel_ready',             #drop because all are F
           'requires_license',                     #drop becuase all are F
           'calculated_host_listings_count',       #drop because repeated
           'host_response_time',                   #drop because these are obtained after you have been a host
           'host_response_rate',                   
           'host_acceptance_rate',
           'host_neighbourhood',
           'host_location',
           'zipcode',                             #drop zipcode, can interpret area 
           'market',                              #drop market as it just refers to SG
           'neighbourhood',                       #drop cause repeated 
           'street',                              #drop cause the column is not useful
           'smart_location',                      #drop cause the column is messy, does not contribute much            
           'calendar_updated']                    #drop cause the column is messy, does not contribute much   

airbnb_data = airbnb_data.drop(drop_col, axis=1)

# %% [markdown]
# ### Data cleaning: Null Values
# Looking at remaining null and missing values.

# %%
# remaining null values

airbnb_data.isnull().sum().sort_values(ascending=False).head()
# Out:
# license             7423
# square_feet         7387
# weekly_price        6948
# monthly_price       6867
# security_deposit    2201
# dtype: int64

# %%
# drop columns that have >80% missing values as we will not be able to infer much
airbnb_data = airbnb_data.drop(['license',
                                'square_feet',
                                'weekly_price',
                                'monthly_price'], axis=1)

# %%
# fill in 0 for security_deposit, cleaning fee as nan just indicates that there is zero security_deposit and cleaning_fee

airbnb_data = airbnb_data.fillna({'security_deposit':0,'cleaning_fee':0})

# %%
# fill in mean for beds, bedrooms, bathrooms indicate that there isnt one present for that house

for col in ['bathrooms', 'bedrooms', 'beds']:
    airbnb_data[col].fillna(airbnb_data[col].median(), inplace=True)

# %%
airbnb_data[airbnb_data.isnull().any(axis=1)]

# no more null values
# Out:
# Empty DataFrame
# Columns: [id, scrape_id, host_since, host_is_superhost, host_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, has_availability, availability_90, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification]
# Index: []

# %% [markdown]
# ### **Data Cleaning: According to Type**
# Looking through each of the features presented to see if they have been classified under the correct data types.

# %%
airbnb_data.dtypes
# Out:
# id                                    int64
# scrape_id                             int64
# host_since                           object
# host_is_superhost                    object
# host_listings_count                   int64
# host_verifications                   object
# host_has_profile_pic                 object
# host_identity_verified               object
# neighbourhood_cleansed               object
# neighbourhood_group_cleansed         object
# latitude                            float64
# longitude                           float64
# is_location_exact                    object
# property_type                        object
# room_type                            object
# accommodates                          int64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# bed_type                             object
# amenities                            object
# price                                object
# security_deposit                     object
# cleaning_fee                         object
# guests_included                       int64
# extra_people                         object
# minimum_nights                        int64
# maximum_nights                        int64
# has_availability                     object
# availability_90                       int64
# instant_bookable                     object
# cancellation_policy                  object
# require_guest_profile_picture        object
# require_guest_phone_verification     object
# dtype: object

# %% [markdown]
# **Time Series**
#
# `host_since` is datetime column and can be used as a measure of the number of days that a host has been on the platform. This will only be used for the purpose of EDA as it will not be a useful indicator for price prediction for first time listers.

# %%
# converting to datetime

airbnb_data.host_since = pd.to_datetime(airbnb_data.host_since) 

# calculating the number of days
airbnb_data['host_active'] = (datetime(2020, 2, 27) - airbnb_data.host_since).astype('timedelta64[D]')

# printing mean and median
print("Mean days as host:", round(airbnb_data['host_active'].mean(),0))
print("Median days as host:", airbnb_data['host_active'].median())

# replacing null values with the median
airbnb_data.host_active.fillna(airbnb_data.host_active.median(), inplace=True)
# Out:
# Mean days as host: 1405.0
# Median days as host: 1419.0

# %% [markdown]
# **Categorical**
#
# Taking a deeper look into categorical features and cleaning it up.

# %%
# Replacing columns with f/t with 0/1

airbnb_data.replace({'f': 0, 't': 1}, inplace=True)

# Plotting the distribution of numerical and boolean categories
airbnb_data.hist(figsize=(40,40), xlabelsize=20, ylabelsize=20);
plt.tight_layout()

# %% [markdown]
# From the above, it can be seen that several columns only contain one category and can be dropped:

# %%
airbnb_data.drop(['has_availability',
                  'host_has_profile_pic', 
                  'maximum_nights', 
                  'require_guest_phone_verification', 
                  'require_guest_profile_picture',
                  'scrape_id'], axis=1, inplace=True)

# %% [markdown]
# #### Numerical
#
# Taking a deeper look with numerical features and cleaning it up.

# %%
# convert price to integer, string because of currency
airbnb_data.price = airbnb_data.price.str[1:-3]
airbnb_data.price = airbnb_data.price.str.replace(",", "")
airbnb_data.price = airbnb_data.price.astype('int64')

# %%
# convert price to integer, string because of currency
airbnb_data.cleaning_fee = airbnb_data.cleaning_fee.str.replace("$", "")
airbnb_data.cleaning_fee = airbnb_data.cleaning_fee.fillna(0)
airbnb_data.cleaning_fee = airbnb_data.cleaning_fee.astype('float64')

# %%
# convert price to integer, string because of currency
airbnb_data.security_deposit = airbnb_data.security_deposit.str.replace("$", "")
airbnb_data.security_deposit = airbnb_data.security_deposit.str.replace(",", "")
airbnb_data.security_deposit = airbnb_data.security_deposit.fillna(0)
airbnb_data.security_deposit = airbnb_data.security_deposit.astype('float64')

# %%
# convert price to integer, string because of currency
airbnb_data.extra_people = airbnb_data.extra_people.str.replace("$", "")
airbnb_data.extra_people = airbnb_data.extra_people.fillna(0)
airbnb_data.extra_people = airbnb_data.extra_people.astype('float64')

# %%
# overview of statistical summary on numeric data, to check if data makes sense
pd.set_option('float_format', '{:f}'.format)
airbnb_data.describe().T.round(5)
# Out:
#                              count            mean             std  \
# id                     7429.000000 25675551.576660 11780700.700390
# host_is_superhost      7429.000000        0.160450        0.367050
# host_listings_count    7429.000000       40.262080       71.369650
# host_identity_verified 7429.000000        0.233010        0.422770
# latitude               7429.000000        1.314090        0.030590
# longitude              7429.000000      103.849240        0.042230
# is_location_exact      7429.000000        0.721360        0.448360
# accommodates           7429.000000        3.366270        2.588870
# bathrooms              7429.000000        1.546980        1.128260
# bedrooms               7429.000000        1.346480        0.975480
# beds                   7429.000000        2.016830        2.475590
# price                  7429.000000      168.911560      330.337810
# security_deposit       7429.000000      177.971730      441.462930
# cleaning_fee           7429.000000       28.039710       38.560810
# guests_included        7429.000000        1.941710        1.695750
# extra_people           7429.000000       15.013190       22.067970
# minimum_nights         7429.000000       18.706690       46.323220
# availability_90        7429.000000       58.876300       35.860440
# instant_bookable       7429.000000        0.475570        0.499440
# host_active            7429.000000     1404.857850      764.818850
#
#                                 min             25%             50%  \
# id                     49091.000000 16421683.000000 27239761.000000
# host_is_superhost          0.000000        0.000000        0.000000
# host_listings_count        0.000000        1.000000        8.000000
# host_identity_verified     0.000000        0.000000        0.000000
# latitude                   1.243870        1.296490        1.311180
# longitude                103.646560      103.837830      103.850880
# is_location_exact          0.000000        0.000000        1.000000
# accommodates               1.000000        2.000000        2.000000
# bathrooms                  0.000000        1.000000        1.000000
# bedrooms                   0.000000        1.000000        1.000000
# beds                       0.000000        1.000000        1.000000
# price                      0.000000       64.000000      120.000000
# security_deposit           0.000000        0.000000        0.000000
# cleaning_fee               0.000000        0.000000       20.000000
# guests_included            1.000000        1.000000        1.000000
# extra_people               0.000000        0.000000       10.000000
# minimum_nights             1.000000        1.000000        3.000000
# availability_90            0.000000       26.000000       79.000000
# instant_bookable           0.000000        0.000000        0.000000
# host_active                3.000000      775.000000     1419.000000
#
#                                    75%             max
# id                     35818917.000000 42578709.000000
# host_is_superhost             0.000000        1.000000
# host_listings_count          45.000000      399.000000
# host_identity_verified        0.000000        1.000000
# latitude                      1.321920        1.454590
# longitude                   103.868810      103.973420
# is_location_exact             1.000000        1.000000
# accommodates                  4.000000       16.000000
# bathrooms                     2.000000       16.000000
# bedrooms                      2.000000       15.000000
# beds                          2.000000       58.000000
# price                       196.000000    10000.000000
# security_deposit            200.000000     6990.000000
# cleaning_fee                 40.000000      600.000000
# guests_included               2.000000       50.000000
# extra_people                 22.000000      404.000000
# minimum_nights               14.000000     1000.000000
# availability_90              89.000000       90.000000
# instant_bookable              1.000000        1.000000
# host_active                1941.000000     3895.000000

# %% [markdown]
# ## EDA
# ### Distribution of Target Value - Price

# %%
# Importing the Singapore neighbourhoods GeoJSON file as a dataframe in geopandas
map_df = gpd.read_file('../data/neighbourhoods.geojson')
map_df.head()
# Out:
#   neighbourhood neighbourhood_group  \
# 0     Pasir Ris         East Region
# 1       Seletar   North-East Region
# 2  Sungei Kadut        North Region
# 3       Orchard      Central Region
# 4       Simpang        North Region
#
#                                             geometry
# 0  MULTIPOLYGON (((103.95322 1.38201, 103.95350 1...
# 1  MULTIPOLYGON (((103.88691 1.42649, 103.88812 1...
# 2  MULTIPOLYGON (((103.76440 1.44345, 103.76443 1...
# 3  MULTIPOLYGON (((103.84298 1.30001, 103.84294 1...
# 4  MULTIPOLYGON (((103.86350 1.43433, 103.86361 1...

# %%
# Creating a dataframe of listing counts and median price by area
area_df = pd.DataFrame(airbnb_data.groupby('neighbourhood_cleansed').size())
area_df.rename(columns={0: 'number_of_listings'}, inplace=True)
area_df['median_price'] = airbnb_data.groupby('neighbourhood_cleansed').price.median().values

# Joining the dataframes
sg_map_df = map_df.set_index('neighbourhood').join(area_df)

# %%
# Plotting the number of listings in each borough
fig1, ax1 = plt.subplots(1, figsize=(15, 6))
sg_map_df.plot(column='number_of_listings', cmap='Blues', ax=ax1)
ax1.axis('off')
ax1.set_title('Number of Airbnb listings in Singapore', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=9000))
sm._A = [] # Creates an empty array for the data range
cbar = fig1.colorbar(sm)
plt.show()

# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 6))
sg_map_df.plot(column='median_price', cmap='Blues', ax=ax2)
ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in Singapore', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=min(sg_map_df.median_price), vmax=max(sg_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.show()

# %%
airbnb_data.loc[airbnb_data.price>9]
# Out:
#             id host_since  host_is_superhost  host_listings_count  \
# 0        49091 2010-10-20                  0                    2
# 1        50646 2010-09-08                  0                    1
# 2        56334 2010-10-20                  0                    2
# 3        71609 2011-01-29                  0                    8
# 4        71896 2011-01-29                  0                    8
# ...        ...        ...                ...                  ...
# 8042  42573423 2015-04-19                  0                   27
# 8043  42573664 2015-04-19                  0                   27
# 8044  42573768 2015-04-19                  0                   27
# 8045  42578518 2015-04-19                  0                   27
# 8046  42578709 2015-04-19                  0                   27
#
#                                      host_verifications  \
# 0     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1     ['email', 'phone', 'facebook', 'reviews', 'off...
# 2     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3     ['email', 'phone', 'reviews', 'manual_offline'...
# 4     ['email', 'phone', 'reviews', 'manual_offline'...
# ...                                                 ...
# 8042  ['email', 'phone', 'jumio', 'offline_governmen...
# 8043  ['email', 'phone', 'jumio', 'offline_governmen...
# 8044  ['email', 'phone', 'jumio', 'offline_governmen...
# 8045  ['email', 'phone', 'jumio', 'offline_governmen...
# 8046  ['email', 'phone', 'jumio', 'offline_governmen...
#
#       host_identity_verified neighbourhood_cleansed  \
# 0                          0              Woodlands
# 1                          0            Bukit Timah
# 2                          0              Woodlands
# 3                          1               Tampines
# 4                          1               Tampines
# ...                      ...                    ...
# 8042                       0                 Rochor
# 8043                       0                 Rochor
# 8044                       0                 Rochor
# 8045                       0              Toa Payoh
# 8046                       0              Toa Payoh
#
#      neighbourhood_group_cleansed  latitude  longitude  is_location_exact  \
# 0                    North Region  1.442550 103.795800                  1
# 1                  Central Region  1.332350 103.785210                  1
# 2                    North Region  1.442460 103.796670                  1
# 3                     East Region  1.345410 103.957120                  1
# 4                     East Region  1.345670 103.959630                  1
# ...                           ...       ...        ...                ...
# 8042               Central Region  1.312086 103.854106                  1
# 8043               Central Region  1.312086 103.854106                  1
# 8044               Central Region  1.312086 103.854106                  1
# 8045               Central Region  1.330277 103.867404                  1
# 8046               Central Region  1.330277 103.867404                  1
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  \
# 0        Apartment     Private room             1   1.000000  1.000000
# 1        Apartment     Private room             2   1.000000  1.000000
# 2        Apartment     Private room             1   1.000000  1.000000
# 3            Villa     Private room             6   1.000000  2.000000
# 4            House     Private room             3   0.500000  1.000000
# ...            ...              ...           ...        ...       ...
# 8042   Condominium  Entire home/apt             6   1.500000  2.000000
# 8043   Condominium  Entire home/apt             6   1.500000  2.000000
# 8044   Condominium  Entire home/apt             6   1.500000  2.000000
# 8045   Condominium  Entire home/apt             3   1.500000  1.000000
# 8046   Condominium  Entire home/apt             3   1.500000  1.000000
#
#          beds  bed_type                                          amenities  \
# 0    1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1    1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2    1.000000  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...
# 3    3.000000  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 4    1.000000  Real Bed  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...
# ...       ...       ...                                                ...
# 8042 3.000000  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 8043 3.000000  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 8044 3.000000  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 8045 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,Kitchen,Gym,E...
# 8046 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,Kitchen,Gym,E...
#
#       price  security_deposit  cleaning_fee  guests_included  extra_people  \
# 0        84          0.000000      0.000000                1     14.000000
# 1        80          0.000000      0.000000                2     20.000000
# 2        70          0.000000      0.000000                1     14.000000
# 3       207        279.000000     56.000000                4     28.000000
# 4        95        140.000000     28.000000                1     21.000000
# ...     ...               ...           ...              ...           ...
# 8042    187        200.000000     60.000000                4     20.000000
# 8043    185        200.000000     60.000000                4     20.000000
# 8044    178        200.000000     60.000000                4     20.000000
# 8045    150        200.000000     40.000000                2     20.000000
# 8046    143        200.000000     40.000000                2     20.000000
#
#       minimum_nights  availability_90  instant_bookable  \
# 0                180               90                 0
# 1                 90               90                 0
# 2                  6               90                 0
# 3                  1               90                 1
# 4                  1               90                 1
# ...              ...              ...               ...
# 8042               3               90                 1
# 8043               7               90                 0
# 8044              28               90                 0
# 8045               7               90                 0
# 8046              28               90                 0
#
#               cancellation_policy  host_active
# 0                        flexible  3417.000000
# 1                        moderate  3459.000000
# 2                        flexible  3417.000000
# 3                        flexible  3316.000000
# 4                        moderate  3316.000000
# ...                           ...          ...
# 8042  strict_14_with_grace_period  1775.000000
# 8043  strict_14_with_grace_period  1775.000000
# 8044  strict_14_with_grace_period  1775.000000
# 8045  strict_14_with_grace_period  1775.000000
# 8046  strict_14_with_grace_period  1775.000000
#
# [7428 rows x 29 columns]

# %% [markdown]
# From the first figure, we see that majority of the airbnb listings are located mainly at the **central regions**.
#
# From the second figure, we see that the median price of airbnb listing in most areas in Singapore falls mainly below $2000, with the exception of Tuas which has the darkest part on the map. We will look into that later on.

# %%
print(f"Cost of an airbnb apartment for one night in Singapore range from ${min(airbnb_data.price)} to ${max(airbnb_data.price)}.")
# Out:
# Cost of an airbnb apartment for one night in Singapore range from $0 to $10000.

# %%
# price should not be zero

airbnb_data.loc[airbnb_data['price']==0,:]

# drop the one that contains zero
# Out:
#             id host_since  host_is_superhost  host_listings_count  \
# 2825  21408571 2017-02-03                  0                    5
#
#                                      host_verifications  \
# 2825  ['email', 'phone', 'facebook', 'google', 'revi...
#
#       host_identity_verified neighbourhood_cleansed  \
# 2825                       1                 Rochor
#
#      neighbourhood_group_cleansed  latitude  longitude  is_location_exact  \
# 2825               Central Region  1.309540 103.852710                  1
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  \
# 2825   Condominium  Entire home/apt             2   1.000000  1.000000
#
#          beds  bed_type                                          amenities  \
# 2825 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
#
#       price  security_deposit  cleaning_fee  guests_included  extra_people  \
# 2825      0          0.000000     15.000000                1     10.000000
#
#       minimum_nights  availability_90  instant_bookable cancellation_policy  \
# 2825               1               69                 1            moderate
#
#       host_active
# 2825  1119.000000

# %%
airbnb_data = airbnb_data.loc[airbnb_data['price']>0,:]

# %%
# Distribution of prices from $1 to $10000
plt.figure(figsize=(20,8))
airbnb_data.price.hist(bins=100)
plt.margins(x=0)
plt.title("Airbnb Prices for one night stay in Singapore up to $10000", fontsize=20)
plt.xlabel("Price ($)")
plt.ylabel("Number of listings")
plt.show()

# %%
# distribution plot below shows that the price is slightly skewed to the right 
# that is longer tail at right, mean>mode.

print(f"Skew is: {airbnb_data.price.skew()}")

#Try to convert to log scale and check the skewness
print(f"After convert to log scale, skew is: {np.log(airbnb_data.price).skew()}")
# The skewness is much closer to 0, which is closer to normal distribution
# Out:
# Skew is: 18.63032870062051
# After convert to log scale, skew is: 0.35905855777584017

# %%
# view the distribution of prices after log
plt.figure(figsize=(20,8))
np.log(airbnb_data.price).hist(bins=100, range=(1,10))
plt.margins(x=0)
# plt.axvline(1, color='orange', linestyle='--')
plt.title("Airbnb Prices for one night stay in Singapore", fontsize=20)
plt.xlabel("Log Price ($)")
plt.ylabel("Number of listings")
plt.show()

# %%
# the target SalePrice normally distributed in log scale
# thus will convert it to log scale
airbnb_data.price = np.log(airbnb_data.price)

# %% [markdown]
# #### Latitude and Longitude
#
# I willput aside these two columns for the time being, perhaps they will come in useful later.

# %%
airbnb_data.plot.scatter(x='longitude', y='latitude', c='price', figsize=(10,10), cmap = 'cool',alpha = 0.5);

# %%
lat_long = airbnb_data[['latitude', 'longitude']]

# %%
lat_long.to_csv('../data/lat_long.csv', index = False)

# %% [markdown]
# ### Time Series Features

# %%
print(f"Of the Airbnb hosts that are still listing on the site, the first joined on {min(airbnb_data.host_since).strftime('%d %B %Y')}, and the most recent joined on {max(airbnb_data.host_since).strftime('%d %B %Y')}.")
# Out:
# Of the Airbnb hosts that are still listing on the site, the first joined on 29 June 2009, and the most recent joined on 24 February 2020.

# %%
plt.figure(figsize=(15,5))
airbnb_data.set_index('host_since').resample('MS').size().plot(label='Hosts joining Airbnb', color='royalblue')
plt.title('Singapore hosts joining Airbnb')
plt.legend()
plt.xlim('2009-06-29', '2020-02-24') # Limiting to whole months
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.boxplot(airbnb_data.host_since.dt.year, airbnb_data.host_listings_count)
plt.xlabel('Year that the host joined Airbnb', fontsize=12)
plt.ylabel('Number of listings per host', fontsize=12)
plt.title('Change per year in the number of listings per host on Airbnb in Singapore', fontsize=16)
plt.show()

# %% [markdown]
# ### Categorical Features

# %%
# List out all the categorical features
cat_features = airbnb_data.select_dtypes(include=[object])

# Return a subset of the DataFrame’s columns based on the column dtypes = object
print(f' Total number of categorical features: {cat_features.shape[1]}')
cat_features.dtypes
# Out:
#  Total number of categorical features: 8
# host_verifications              object
# neighbourhood_cleansed          object
# neighbourhood_group_cleansed    object
# property_type                   object
# room_type                       object
# bed_type                        object
# amenities                       object
# cancellation_policy             object
# dtype: object

# %% [markdown]
# #### host_verifications

# %%
airbnb_data.host_verifications[:5]
# Out:
# 0    ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1    ['email', 'phone', 'facebook', 'reviews', 'off...
# 2    ['email', 'phone', 'facebook', 'reviews', 'jum...
# 3    ['email', 'phone', 'reviews', 'manual_offline'...
# 4    ['email', 'phone', 'reviews', 'manual_offline'...
# Name: host_verifications, dtype: object

# %%
airbnb_data.host_verifications = airbnb_data.host_verifications.str.replace('[', '')
airbnb_data.host_verifications = airbnb_data.host_verifications.str.replace(']', ',')
airbnb_data.host_verifications = airbnb_data.host_verifications.str.replace('"', '')
airbnb_data.host_verifications = airbnb_data.host_verifications.str.replace("'", '')
airbnb_data.host_verifications = airbnb_data.host_verifications.str.split(',')
airbnb_data.host_verifications = airbnb_data.host_verifications.str.join(',')

# %%
host_verification_list = list(airbnb_data.host_verifications)
host_verification_list = " ".join(host_verification_list)
host_verification_list = [x.strip() for x in host_verification_list.split(',')]
host_verification_list_clean = set(host_verification_list)

# %%
host_verification_list_clean
# Out:
# {'',
#  'email',
#  'facebook',
#  'google',
#  'government_id',
#  'identity_manual',
#  'jumio',
#  'kba',
#  'manual_offline',
#  'manual_online',
#  'offline_government_id',
#  'phone',
#  'reviews',
#  'selfie',
#  'sesame',
#  'sesame_offline',
#  'weibo',
#  'work_email',
#  'zhima_selfie'}

# %%
host_verification_list = pd.Series(host_verification_list)
host_verification_count_top20 = host_verification_list.value_counts().head(20)
host_verification_count_top20
# Out:
# phone                    7390
# email                    6709
# government_id            5428
# reviews                  4411
# jumio                    3943
# offline_government_id    3605
# selfie                   3014
# identity_manual          2747
# work_email                975
# facebook                  564
# google                    378
# weibo                     198
# manual_offline             89
# zhima_selfie               46
# kba                        19
# manual_online              17
#                            14
# sesame_offline              4
# sesame                      4
# dtype: int64

# %% [markdown]
# In the list above, some of the methods for host verification are more popular. Since there are a couple of overlaps, I will group these into main categories.
#
# The host verification chosen are (slashes indicate separate categories that can be combined):
#
# + **phone:** phone
# + **email:** email/work_email
# + **id:** government_id/offline_government_id
# + **review:** reviews
# + **photo:** selfie/zhima_selfie
# + **socials:** facebook/google/weibo
# + **others:** jumio/identity_manual/manual_offline/manual_online/sesame/sesame_onffline/kba

# %%
airbnb_data.loc[airbnb_data['host_verifications'].str.contains('phone'), 'phone'] = 'true'

# %%
# creating new columns whereby specific host verification is present

airbnb_data['phone'] = pd.np.where(airbnb_data.host_verifications.str.contains('phone'),1,0)
airbnb_data['email'] = pd.np.where(airbnb_data.host_verifications.str.contains('email|work_email'),1,0)
airbnb_data['id_verification'] = pd.np.where(airbnb_data.host_verifications.str.contains('government_id|offline_government_id'),1,0)
airbnb_data['review'] = pd.np.where(airbnb_data.host_verifications.str.contains('reviews'),1,0)
airbnb_data['photo'] = pd.np.where(airbnb_data.host_verifications.str.contains('selfie|zhima_selfie'),1,0)
airbnb_data['socials'] = pd.np.where(airbnb_data.host_verifications.str.contains('facebook|google|weibo'),1,0)
airbnb_data['others'] = pd.np.where(airbnb_data.host_verifications.str.contains('jumio|identity_manual|manual_offline|manual_online|sesame|sesame_offline|kba'),1,0)

# %%
airbnb_data.id
# Out:
# 0          49091
# 1          50646
# 2          56334
# 3          71609
# 4          71896
#           ...
# 8042    42573423
# 8043    42573664
# 8044    42573768
# 8045    42578518
# 8046    42578709
# Name: id, Length: 7428, dtype: int64

# %% [markdown]
# Since I have categorized this into boolean categories, I will continue with the `host_verification` EDA later on, looking at it as numerical features.

# %%
# Define function to plot boxplot for categorical feature

def boxplot_(df, x_col, y_col, xlabel, ylabel, title, p,q):
    plt.figure(figsize = (p,q))
    
    # boxplot using seaborn
    ax = sns.boxplot(x=x_col, y=y_col, data=df);
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    # Calculate number of occurance (counts) per category & median to position the counts in boxplot
    medians = airbnb_data.groupby([x_col])[y_col].median().values
    counts = airbnb_data[x_col].value_counts().values     # count the number of occurance for each category
    counts = [str(x) for x in counts.tolist()]
    counts = ["n: " + i for i in counts]
 
    # Add it to the plot
    pos = range(len(counts))
    for tick,label in zip(pos,ax.get_xticklabels()):
        ax.text(pos[tick], medians[tick] + 0.03, counts[tick],
            horizontalalignment='center', size='x-small', color='k', weight='semibold')

# %%
airbnb_data[(airbnb_data.neighbourhood_cleansed == 'Southern Islands')]
# Out:
#             id host_since  host_is_superhost  host_listings_count  \
# 1093  10638837 2015-12-13                  0                    2
# 1271  12097789 2013-11-11                  0                    4
# 1351  12738797 2013-11-11                  0                    4
# 1400  13117403 2013-11-11                  0                    4
# 1628  14620083 2013-11-11                  0                    4
# 1887  16395877 2016-07-18                  0                   10
# 2838  21451655 2016-07-18                  0                   10
# 3104  22617828 2016-07-18                  0                   10
# 3154  22945402 2016-07-18                  0                   10
# 3159  22986772 2016-07-18                  0                   10
# 3160  22987047 2016-07-18                  0                   10
# 4306  29454824 2015-04-22                  1                    6
# 4827  31527262 2018-01-29                  0                    2
# 4840  31604616 2017-07-05                  0                  239
# 4862  31776450 2016-09-05                  0                    1
# 6910  40012885 2019-11-08                  0                   16
# 6930  40075693 2019-11-08                  0                   16
# 6963  40179744 2019-11-08                  0                   16
# 7020  40351844 2015-04-22                  1                    6
# 7023  40356687 2019-11-08                  0                   16
# 7044  40442787 2019-11-08                  0                   16
# 7203  40830359 2019-11-08                  0                   16
# 7722  42033574 2015-04-22                  1                    6
# 7735  42051696 2015-04-22                  1                    6
# 7740  42052647 2015-04-22                  1                    6
#
#                                      host_verifications  \
# 1093  email, phone, facebook, reviews, jumio, offlin...
# 1271              phone, reviews, jumio, government_id,
# 1351              phone, reviews, jumio, government_id,
# 1400              phone, reviews, jumio, government_id,
# 1628              phone, reviews, jumio, government_id,
# 1887                email, phone, facebook, work_email,
# 2838                email, phone, facebook, work_email,
# 3104                email, phone, facebook, work_email,
# 3154                email, phone, facebook, work_email,
# 3159                email, phone, facebook, work_email,
# 3160                email, phone, facebook, work_email,
# 4306  email, phone, reviews, jumio, offline_governme...
# 4827  email, phone, jumio, offline_government_id, se...
# 4840  email, phone, reviews, jumio, offline_governme...
# 4862  email, phone, jumio, offline_government_id, go...
# 6910  email, phone, jumio, offline_government_id, se...
# 6930  email, phone, jumio, offline_government_id, se...
# 6963  email, phone, jumio, offline_government_id, se...
# 7020  email, phone, reviews, jumio, offline_governme...
# 7023  email, phone, jumio, offline_government_id, se...
# 7044  email, phone, jumio, offline_government_id, se...
# 7203  email, phone, jumio, offline_government_id, se...
# 7722  email, phone, reviews, jumio, offline_governme...
# 7735  email, phone, reviews, jumio, offline_governme...
# 7740  email, phone, reviews, jumio, offline_governme...
#
#       host_identity_verified neighbourhood_cleansed  \
# 1093                       1       Southern Islands
# 1271                       0       Southern Islands
# 1351                       0       Southern Islands
# 1400                       0       Southern Islands
# 1628                       0       Southern Islands
# 1887                       0       Southern Islands
# 2838                       0       Southern Islands
# 3104                       0       Southern Islands
# 3154                       0       Southern Islands
# 3159                       0       Southern Islands
# 3160                       0       Southern Islands
# 4306                       0       Southern Islands
# 4827                       0       Southern Islands
# 4840                       0       Southern Islands
# 4862                       0       Southern Islands
# 6910                       0       Southern Islands
# 6930                       0       Southern Islands
# 6963                       0       Southern Islands
# 7020                       0       Southern Islands
# 7023                       0       Southern Islands
# 7044                       0       Southern Islands
# 7203                       0       Southern Islands
# 7722                       0       Southern Islands
# 7735                       0       Southern Islands
# 7740                       0       Southern Islands
#
#      neighbourhood_group_cleansed  latitude  longitude  is_location_exact  \
# 1093               Central Region  1.243910 103.839150                  1
# 1271               Central Region  1.250400 103.825390                  1
# 1351               Central Region  1.248530 103.825020                  1
# 1400               Central Region  1.248950 103.823920                  1
# 1628               Central Region  1.249180 103.825090                  1
# 1887               Central Region  1.252840 103.822250                  0
# 2838               Central Region  1.250460 103.825290                  1
# 3104               Central Region  1.250540 103.825510                  1
# 3154               Central Region  1.249920 103.824410                  1
# 3159               Central Region  1.248810 103.823640                  0
# 3160               Central Region  1.248470 103.823890                  0
# 4306               Central Region  1.256020 103.821000                  1
# 4827               Central Region  1.245260 103.839990                  0
# 4840               Central Region  1.250880 103.824820                  1
# 4862               Central Region  1.243870 103.842460                  1
# 6910               Central Region  1.256400 103.820560                  0
# 6930               Central Region  1.257330 103.819060                  0
# 6963               Central Region  1.257620 103.819790                  0
# 7020               Central Region  1.257460 103.817800                  1
# 7023               Central Region  1.254610 103.821020                  0
# 7044               Central Region  1.256060 103.819510                  0
# 7203               Central Region  1.254430 103.820900                  0
# 7722               Central Region  1.256360 103.819470                  1
# 7735               Central Region  1.257350 103.819450                  1
# 7740               Central Region  1.258000 103.820530                  1
#
#            property_type        room_type  accommodates  bathrooms  bedrooms  \
# 1093         Condominium  Entire home/apt             6   2.500000  3.000000
# 1271           Apartment  Entire home/apt             5   2.000000  2.000000
# 1351  Serviced apartment  Entire home/apt             2   1.000000  1.000000
# 1400           Apartment  Entire home/apt             6   3.500000  3.000000
# 1628           Apartment  Entire home/apt             6   3.500000  3.000000
# 1887               House  Entire home/apt             7   3.500000  3.000000
# 2838           Apartment  Entire home/apt             5   2.000000  2.000000
# 3104               House  Entire home/apt             6   3.500000  0.000000
# 3154  Serviced apartment  Entire home/apt             2   1.000000  1.000000
# 3159  Serviced apartment  Entire home/apt             5   2.500000  2.000000
# 3160  Serviced apartment  Entire home/apt             7   3.500000  3.000000
# 4306               Hotel     Private room             4   2.000000  1.000000
# 4827                Boat  Entire home/apt             2   1.000000  1.000000
# 4840         Condominium  Entire home/apt             4   2.000000  2.000000
# 4862         Condominium  Entire home/apt             6   4.500000  3.000000
# 6910               Hotel     Private room             4   1.000000  1.000000
# 6930               Hotel     Private room             2   1.000000  1.000000
# 6963               Hotel     Private room             3   1.000000  1.000000
# 7020               Hotel     Private room             3   1.000000  1.000000
# 7023               Hotel     Private room             3   1.000000  1.000000
# 7044               Hotel     Private room             2   1.000000  1.000000
# 7203               Hotel     Private room             2   1.000000  1.000000
# 7722               Hotel     Private room             3   1.500000  1.000000
# 7735               Hotel     Private room             4   1.000000  1.000000
# 7740               Hotel     Private room             4   1.000000  1.000000
#
#          beds  bed_type                                          amenities  \
# 1093 3.000000  Real Bed  {TV,"Air conditioning",Pool,Kitchen,Gym,Elevat...
# 1271 3.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1351 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1400 4.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1628 4.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1887 4.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2838 3.000000  Real Bed  {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 3104 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3154 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3159 3.000000  Real Bed  {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 3160 4.000000  Real Bed  {TV,Internet,Wifi,"Air conditioning",Pool,Kitc...
# 4306 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,Elevator,"Hot...
# 4827 1.000000  Real Bed  {TV,"Air conditioning","Paid parking off premi...
# 4840 3.000000  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 4862 3.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...
# 6910 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 6930 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 6963 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7020 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7023 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7044 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7203 1.000000  Real Bed  {TV,Wifi,Pool,"Free parking on premises",Gym,E...
# 7722 3.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7735 3.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7740 2.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
#
#         price  security_deposit  cleaning_fee  guests_included  extra_people  \
# 1093 6.173786        200.000000     60.000000                4     50.000000
# 1271 7.166266        150.000000      0.000000                4    112.000000
# 1351 6.639876        150.000000      0.000000                2    120.000000
# 1400 8.323608        150.000000      0.000000                6    112.000000
# 1628 7.987185        150.000000      0.000000                6    112.000000
# 1887 9.093694        150.000000      0.000000                7    112.000000
# 2838 7.166266          0.000000      0.000000                1      0.000000
# 3104 9.093807          0.000000      0.000000                1      0.000000
# 3154 5.811141       4500.000000      0.000000                1    120.000000
# 3159 6.291569        150.000000      0.000000                1    120.000000
# 3160 6.552508          0.000000      0.000000                1    120.000000
# 4306 7.215975          0.000000      0.000000                1      0.000000
# 4827 5.298317          0.000000     40.000000                2     30.000000
# 4840 8.994917          0.000000    200.000000                1      0.000000
# 4862 6.672033       2500.000000      0.000000                1      0.000000
# 6910 5.855072          0.000000      0.000000                1      0.000000
# 6930 5.996452          0.000000      0.000000                1      0.000000
# 6963 5.680173          0.000000      0.000000                1      0.000000
# 7020 7.365180          0.000000      0.000000                1      0.000000
# 7023 5.627621          0.000000      0.000000                1      0.000000
# 7044 5.680173          0.000000      0.000000                1      0.000000
# 7203 6.272877          0.000000      0.000000                1      0.000000
# 7722 5.521461        200.000000     25.000000                2     90.000000
# 7735 5.521461        200.000000     20.000000                1      0.000000
# 7740 5.521461        200.000000     20.000000                3     90.000000
#
#       minimum_nights  availability_90  instant_bookable  \
# 1093               3                0                 0
# 1271               3                0                 0
# 1351               3                0                 0
# 1400               3               27                 0
# 1628               1               57                 0
# 1887               2               57                 0
# 2838               3               88                 0
# 3104               2                0                 1
# 3154              25               57                 0
# 3159              30               83                 0
# 3160              30               88                 0
# 4306               1               90                 0
# 4827               1               81                 1
# 4840               1               89                 0
# 4862              14               82                 1
# 6910               1               81                 1
# 6930               1               89                 1
# 6963               1               89                 1
# 7020               1               90                 0
# 7023               1               89                 1
# 7044               1               90                 1
# 7203               1               83                 1
# 7722               1               90                 0
# 7735               1               78                 0
# 7740               1               85                 0
#
#               cancellation_policy  host_active  phone  email  id_verification  \
# 1093  strict_14_with_grace_period  1537.000000      1      1                1
# 1271  strict_14_with_grace_period  2299.000000      1      0                1
# 1351  strict_14_with_grace_period  2299.000000      1      0                1
# 1400  strict_14_with_grace_period  2299.000000      1      0                1
# 1628  strict_14_with_grace_period  2299.000000      1      0                1
# 1887  strict_14_with_grace_period  1319.000000      1      1                0
# 2838  strict_14_with_grace_period  1319.000000      1      1                0
# 3104  strict_14_with_grace_period  1319.000000      1      1                0
# 3154  strict_14_with_grace_period  1319.000000      1      1                0
# 3159  strict_14_with_grace_period  1319.000000      1      1                0
# 3160  strict_14_with_grace_period  1319.000000      1      1                0
# 4306  strict_14_with_grace_period  1772.000000      1      1                1
# 4827  strict_14_with_grace_period   759.000000      1      1                1
# 4840  strict_14_with_grace_period   967.000000      1      1                1
# 4862                     flexible  1270.000000      1      1                1
# 6910  strict_14_with_grace_period   111.000000      1      1                1
# 6930                     flexible   111.000000      1      1                1
# 6963  strict_14_with_grace_period   111.000000      1      1                1
# 7020  strict_14_with_grace_period  1772.000000      1      1                1
# 7023  strict_14_with_grace_period   111.000000      1      1                1
# 7044  strict_14_with_grace_period   111.000000      1      1                1
# 7203                     flexible   111.000000      1      1                1
# 7722  strict_14_with_grace_period  1772.000000      1      1                1
# 7735  strict_14_with_grace_period  1772.000000      1      1                1
# 7740  strict_14_with_grace_period  1772.000000      1      1                1
#
#       review  photo  socials  others
# 1093       1      0        1       1
# 1271       1      0        0       1
# 1351       1      0        0       1
# 1400       1      0        0       1
# 1628       1      0        0       1
# 1887       0      0        1       0
# 2838       0      0        1       0
# 3104       0      0        1       0
# 3154       0      0        1       0
# 3159       0      0        1       0
# 3160       0      0        1       0
# 4306       1      1        0       1
# 4827       0      1        0       1
# 4840       1      1        0       1
# 4862       0      0        0       1
# 6910       0      1        0       1
# 6930       0      1        0       1
# 6963       0      1        0       1
# 7020       1      1        0       1
# 7023       0      1        0       1
# 7044       0      1        0       1
# 7203       0      1        0       1
# 7722       1      1        0       1
# 7735       1      1        0       1
# 7740       1      1        0       1

# %% [markdown]
# #### neighbourhood_cleansed

# %%
boxplot_(airbnb_data,'neighbourhood_cleansed', 'price', 'Neighbourhood', 'Price, SGD',
        'Neighbourhood Versus Price', 26,6)
plt.xticks(rotation=90, fontsize = 14);

# %%
airbnb_data.loc[(airbnb_data.neighbourhood_cleansed == 'Southern Islands')& (airbnb_data.beds<2)]
# Out:
#             id host_since  host_is_superhost  host_listings_count  \
# 1351  12738797 2013-11-11                  0                    4
# 3104  22617828 2016-07-18                  0                   10
# 3154  22945402 2016-07-18                  0                   10
# 4827  31527262 2018-01-29                  0                    2
# 6910  40012885 2019-11-08                  0                   16
# 6930  40075693 2019-11-08                  0                   16
# 7023  40356687 2019-11-08                  0                   16
# 7044  40442787 2019-11-08                  0                   16
# 7203  40830359 2019-11-08                  0                   16
#
#                                      host_verifications  \
# 1351              phone, reviews, jumio, government_id,
# 3104                email, phone, facebook, work_email,
# 3154                email, phone, facebook, work_email,
# 4827  email, phone, jumio, offline_government_id, se...
# 6910  email, phone, jumio, offline_government_id, se...
# 6930  email, phone, jumio, offline_government_id, se...
# 7023  email, phone, jumio, offline_government_id, se...
# 7044  email, phone, jumio, offline_government_id, se...
# 7203  email, phone, jumio, offline_government_id, se...
#
#       host_identity_verified neighbourhood_cleansed  \
# 1351                       0       Southern Islands
# 3104                       0       Southern Islands
# 3154                       0       Southern Islands
# 4827                       0       Southern Islands
# 6910                       0       Southern Islands
# 6930                       0       Southern Islands
# 7023                       0       Southern Islands
# 7044                       0       Southern Islands
# 7203                       0       Southern Islands
#
#      neighbourhood_group_cleansed  latitude  longitude  is_location_exact  \
# 1351               Central Region  1.248530 103.825020                  1
# 3104               Central Region  1.250540 103.825510                  1
# 3154               Central Region  1.249920 103.824410                  1
# 4827               Central Region  1.245260 103.839990                  0
# 6910               Central Region  1.256400 103.820560                  0
# 6930               Central Region  1.257330 103.819060                  0
# 7023               Central Region  1.254610 103.821020                  0
# 7044               Central Region  1.256060 103.819510                  0
# 7203               Central Region  1.254430 103.820900                  0
#
#            property_type        room_type  accommodates  bathrooms  bedrooms  \
# 1351  Serviced apartment  Entire home/apt             2   1.000000  1.000000
# 3104               House  Entire home/apt             6   3.500000  0.000000
# 3154  Serviced apartment  Entire home/apt             2   1.000000  1.000000
# 4827                Boat  Entire home/apt             2   1.000000  1.000000
# 6910               Hotel     Private room             4   1.000000  1.000000
# 6930               Hotel     Private room             2   1.000000  1.000000
# 7023               Hotel     Private room             3   1.000000  1.000000
# 7044               Hotel     Private room             2   1.000000  1.000000
# 7203               Hotel     Private room             2   1.000000  1.000000
#
#          beds  bed_type                                          amenities  \
# 1351 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3104 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3154 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 4827 1.000000  Real Bed  {TV,"Air conditioning","Paid parking off premi...
# 6910 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 6930 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7023 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7044 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,"Free parking...
# 7203 1.000000  Real Bed  {TV,Wifi,Pool,"Free parking on premises",Gym,E...
#
#         price  security_deposit  cleaning_fee  guests_included  extra_people  \
# 1351 6.639876        150.000000      0.000000                2    120.000000
# 3104 9.093807          0.000000      0.000000                1      0.000000
# 3154 5.811141       4500.000000      0.000000                1    120.000000
# 4827 5.298317          0.000000     40.000000                2     30.000000
# 6910 5.855072          0.000000      0.000000                1      0.000000
# 6930 5.996452          0.000000      0.000000                1      0.000000
# 7023 5.627621          0.000000      0.000000                1      0.000000
# 7044 5.680173          0.000000      0.000000                1      0.000000
# 7203 6.272877          0.000000      0.000000                1      0.000000
#
#       minimum_nights  availability_90  instant_bookable  \
# 1351               3                0                 0
# 3104               2                0                 1
# 3154              25               57                 0
# 4827               1               81                 1
# 6910               1               81                 1
# 6930               1               89                 1
# 7023               1               89                 1
# 7044               1               90                 1
# 7203               1               83                 1
#
#               cancellation_policy  host_active  phone  email  id_verification  \
# 1351  strict_14_with_grace_period  2299.000000      1      0                1
# 3104  strict_14_with_grace_period  1319.000000      1      1                0
# 3154  strict_14_with_grace_period  1319.000000      1      1                0
# 4827  strict_14_with_grace_period   759.000000      1      1                1
# 6910  strict_14_with_grace_period   111.000000      1      1                1
# 6930                     flexible   111.000000      1      1                1
# 7023  strict_14_with_grace_period   111.000000      1      1                1
# 7044  strict_14_with_grace_period   111.000000      1      1                1
# 7203                     flexible   111.000000      1      1                1
#
#       review  photo  socials  others
# 1351       1      0        0       1
# 3104       0      0        1       0
# 3154       0      0        1       0
# 4827       0      1        0       1
# 6910       0      1        0       1
# 6930       0      1        0       1
# 7023       0      1        0       1
# 7044       0      1        0       1
# 7203       0      1        0       1

# %%
def plot_scatter_chart(df, feature1, feature2):
    bedsbelow2 = df[(df[feature1] == feature2)&(df.beds<=2)]
    bedsabove2 = df[(df[feature1] == feature2)&(df.beds>2)]
    plt.figure(figsize = (12,6))
    
    plt.scatter(bedsabove2.bedrooms, bedsabove2.price, color='green', marker='x',label = 'beds_above_2')
    plt.scatter(bedsbelow2.bedrooms, bedsbelow2.price, color='blue',label ='beds_below_2')
    plt.xlabel("Total number of bedrooms")
    plt.ylabel("Price")
    plt.title(feature2)
    plt.legend()

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Southern Islands")

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Rochor")

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Toa Payoh")

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Bedok")

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Tuas")

# %%
plot_scatter_chart(airbnb_data, 
                   "neighbourhood_cleansed",
                   "Jurong East")

# %%
airbnb_data.loc[(airbnb_data.price>8.0)&(airbnb_data.beds<2)]
# Out:
#             id host_since  host_is_superhost  host_listings_count  \
# 1066  10343562 2016-01-04                  0                    1
# 1188  11544732 2016-02-29                  0                    1
# 1836  16155549 2016-08-23                  0                    1
# 2381  19218794 2015-06-22                  0                    1
# 2465  19739630 2017-07-08                  0                    1
# 2653  20791161 2017-03-28                  0                    1
# 3104  22617828 2016-07-18                  0                   10
# 6026  36652759 2013-03-27                  0                    0
#
#                                      host_verifications  \
# 1066                                      email, phone,
# 1188                             email, phone, reviews,
# 1836  email, phone, facebook, reviews, jumio, govern...
# 2381  email, phone, reviews, jumio, offline_governme...
# 2465                                      email, phone,
# 2653  email, phone, facebook, reviews, jumio, offlin...
# 3104                email, phone, facebook, work_email,
# 6026  email, phone, jumio, offline_government_id, go...
#
#       host_identity_verified neighbourhood_cleansed  \
# 1066                       0                 Rochor
# 1188                       0                 Outram
# 1836                       1              Toa Payoh
# 2381                       1                  Bedok
# 2465                       0            Jurong East
# 2653                       0                   Tuas
# 3104                       0       Southern Islands
# 6026                       0                  Bedok
#
#      neighbourhood_group_cleansed  latitude  longitude  is_location_exact  \
# 1066               Central Region  1.299430 103.851770                  1
# 1188               Central Region  1.283480 103.841350                  1
# 1836               Central Region  1.333420 103.848970                  0
# 2381                  East Region  1.307630 103.914510                  1
# 2465                  West Region  1.336330 103.725690                  1
# 2653                  West Region  1.319090 103.646560                  0
# 3104               Central Region  1.250540 103.825510                  1
# 6026                  East Region  1.309470 103.921760                  1
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  \
# 1066     Apartment  Entire home/apt             1   1.000000  1.000000
# 1188     Apartment     Private room             1   1.000000  1.000000
# 1836     Apartment     Private room             1   1.000000  1.000000
# 2381     Apartment     Private room             2   1.000000  1.000000
# 2465   Condominium     Private room             2   1.000000  1.000000
# 2653   Condominium  Entire home/apt             3   1.000000  1.000000
# 3104         House  Entire home/apt             6   3.500000  0.000000
# 6026         House  Entire home/apt             6   2.000000  4.000000
#
#          beds  bed_type                                          amenities  \
# 1066 1.000000  Real Bed  {TV,"Cable TV",Internet,"Air conditioning",Poo...
# 1188 1.000000  Real Bed     {Elevator,"First aid kit","Fire extinguisher"}
# 1836 1.000000  Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,Elev...
# 2381 1.000000  Real Bed  {Wifi,"Air conditioning",Pool,"Free parking on...
# 2465 1.000000  Real Bed  {Wifi,"Air conditioning",Kitchen,"Free parking...
# 2653 1.000000  Real Bed  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...
# 3104 1.000000  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 6026 1.000000  Real Bed  {"Air conditioning",Kitchen,"Free parking on p...
#
#         price  security_deposit  cleaning_fee  guests_included  extra_people  \
# 1066 8.160804          0.000000      0.000000                1      0.000000
# 1188 8.853665          0.000000      0.000000                1      0.000000
# 1836 8.294050       2000.000000     70.000000                1      0.000000
# 2381 8.006368        150.000000     30.000000                1     50.000000
# 2465 8.853665       6741.000000      0.000000                1    404.000000
# 2653 9.210340        500.000000     39.000000                1     50.000000
# 3104 9.093807          0.000000      0.000000                1      0.000000
# 6026 8.517393          0.000000      0.000000                1      0.000000
#
#       minimum_nights  availability_90  instant_bookable  \
# 1066             365                0                 0
# 1188               2               90                 0
# 1836               3               90                 0
# 2381              90               90                 0
# 2465               2                0                 0
# 2653               2               89                 0
# 3104               2                0                 1
# 6026             365               90                 1
#
#               cancellation_policy  host_active  phone  email  id_verification  \
# 1066                     flexible  1515.000000      1      1                0
# 1188                     flexible  1459.000000      1      1                0
# 1836  strict_14_with_grace_period  1283.000000      1      1                1
# 2381  strict_14_with_grace_period  1711.000000      1      1                1
# 2465                     flexible   964.000000      1      1                0
# 2653  strict_14_with_grace_period  1066.000000      1      1                1
# 3104  strict_14_with_grace_period  1319.000000      1      1                0
# 6026                     flexible  2528.000000      1      1                1
#
#       review  photo  socials  others
# 1066       0      0        0       0
# 1188       1      0        0       0
# 1836       1      0        1       1
# 2381       1      0        0       1
# 2465       0      0        0       0
# 2653       1      1        1       1
# 3104       0      0        1       0
# 6026       0      0        0       1

# %% [markdown]
# We see an outlier whereby, it is a zero bedroom apartment with less than 2 beds and yet it is still priced very high. I will remove this outlier.

# %%
outlier_rows = (airbnb_data.loc[(airbnb_data.price>8.0)&(airbnb_data.beds<2)].index.values)

# %%
airbnb_data = airbnb_data.drop(outlier_rows, axis ='index')

# %%
# Creating a dataframe of listing counts and median price by area
area_df = pd.DataFrame(airbnb_data.groupby('neighbourhood_cleansed').size())
area_df.rename(columns={0: 'number_of_listings'}, inplace=True)
area_df['median_price'] = airbnb_data.groupby('neighbourhood_cleansed').price.median().values

# Joining the dataframes
sg_map_df = map_df.set_index('neighbourhood').join(area_df)

# %%
# Plotting the number of listings in each borough
fig1, ax1 = plt.subplots(1, figsize=(15, 6))
sg_map_df.plot(column='number_of_listings', cmap='Blues', ax=ax1)
ax1.axis('off')
ax1.set_title('Number of Airbnb listings in Singapore', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=9000))
sm._A = [] # Creates an empty array for the data range
cbar = fig1.colorbar(sm)
plt.show()

# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 6))
sg_map_df.plot(column='median_price', cmap='Blues', ax=ax2)
ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in Singapore', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=min(sg_map_df.median_price), vmax=max(sg_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.show()

# %% [markdown]
# #### neighbourhood_group_cleansed

# %%
boxplot_(airbnb_data,'neighbourhood_group_cleansed', 'price', 'Neighbourhood Grouped', 'Price, SGD',
        'Neighbourhood Grouped Versus Price', 18, 5)

plt.xticks(rotation=45, fontsize = 18);

# %% [markdown]
# #### property_type

# %%
airbnb_data.property_type.value_counts()
# Out:
# Apartment                 3020
# Condominium               2002
# Serviced apartment         728
# House                      525
# Hostel                     281
# Boutique hotel             180
# Hotel                      146
# Loft                       125
# Townhouse                  121
# Bungalow                    63
# Bed and breakfast           62
# Other                       48
# Aparthotel                  33
# Guesthouse                  25
# Guest suite                 24
# Villa                       12
# Tent                         6
# Boat                         6
# Campsite                     3
# Chalet                       3
# Tiny house                   2
# Heritage hotel (India)       1
# Earth house                  1
# Cabin                        1
# Bus                          1
# Farm stay                    1
# Name: property_type, dtype: int64

# %% [markdown]
# In the list above, some of the `property_types` only consist of a couple of listings. Thus, I will group these into main categories, such as apartment, hotel, others.
#
# The property types chosen are categorised as followed:
#
# + **apartment:**
#     - apartment
#     - serviced apartment
#     - condominium
#     - loft
#     - house
#     - tiny house
#     - townhouse
#     - guesthouse
#     - bungalow
# + **hotel:**
#     - boutique hotel
#     - heritage hotel(india)
#     - hotel
#     - aparthotel
# + **others:**
#     - hostel
#     - bed and breakfast
#     - other
#     - guest suite
#     - villa
#     - boat
#     - tent
#     - campsite
#     - chalet
#     - farm stay
#     - bus
#     - cabin
#     - earth house

# %%
airbnb_data.loc[~airbnb_data.property_type.isin(['Apartment',
                                                 'Condominium',
                                                 'Serviced apartment',       
                                                 'House',                    
                                                 'Hostel',                   
                                                 'Boutique hotel',          
                                                 'Hotel',                    
                                                 'Loft',                    
                                                 'Townhouse',
                                                 'Bungalow']),'property_type'] = 'Other'

# %%
boxplot_(airbnb_data,'property_type', 'price', 'Property Type', 'Price, SGD',
        'Property Type Versus Price', 20, 5)


plt.xticks(rotation=90, fontsize = 16);

# %% [markdown]
# #### room_type

# %%
boxplot_(airbnb_data,'room_type', 'price', 'Room Type', 'Price, SGD',
        'Room Type Versus Price', 16,5)


plt.xticks(rotation=90, fontsize = 16);

# %% [markdown]
# #### bed_type

# %%
boxplot_(airbnb_data,'bed_type', 'price', 'Bed Type', 'Price, SGD',
        'Bed Type Versus Price', 16,5)


plt.xticks(rotation=90, fontsize = 16);

# %% [markdown]
# #### amenities

# %%
airbnb_data.amenities[:5]
# Out:
# 0    {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1    {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...
# 3    {TV,Wifi,"Air conditioning",Kitchen,"Pets live...
# 4    {TV,Internet,Wifi,"Air conditioning",Kitchen,"...
# Name: amenities, dtype: object

# %%
airbnb_data.amenities = airbnb_data.amenities.str.replace('{','')
airbnb_data.amenities = airbnb_data.amenities.str.replace('}', ',')
airbnb_data.amenities = airbnb_data.amenities.str.replace('"', '')
airbnb_data.amenities = airbnb_data.amenities.str.split(',')

# %%
airbnb_data.amenities
# Out:
# 0       [TV, Cable TV, Internet, Wifi, Air conditionin...
# 1       [TV, Cable TV, Internet, Wifi, Air conditionin...
# 2       [TV, Cable TV, Wifi, Air conditioning, Kitchen...
# 3       [TV, Wifi, Air conditioning, Kitchen, Pets liv...
# 4       [TV, Internet, Wifi, Air conditioning, Kitchen...
#                               ...
# 8042    [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 8043    [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 8044    [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 8045    [TV, Wifi, Air conditioning, Pool, Kitchen, Gy...
# 8046    [TV, Wifi, Air conditioning, Pool, Kitchen, Gy...
# Name: amenities, Length: 7420, dtype: object

# %%
airbnb_data.amenities = airbnb_data.amenities.str.join(',')

# %%
airbnb_data[['amenities']]
# Out:
#                                               amenities
# 0     TV,Cable TV,Internet,Wifi,Air conditioning,Pet...
# 1     TV,Cable TV,Internet,Wifi,Air conditioning,Poo...
# 2     TV,Cable TV,Wifi,Air conditioning,Kitchen,Pets...
# 3     TV,Wifi,Air conditioning,Kitchen,Pets live on ...
# 4     TV,Internet,Wifi,Air conditioning,Kitchen,Pets...
# ...                                                 ...
# 8042  TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8043  TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8044  TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8045  TV,Wifi,Air conditioning,Pool,Kitchen,Gym,Elev...
# 8046  TV,Wifi,Air conditioning,Pool,Kitchen,Gym,Elev...
#
# [7420 rows x 1 columns]

# %%
# looking at amenities

airbnb_data.amenities
# Out:
# 0       TV,Cable TV,Internet,Wifi,Air conditioning,Pet...
# 1       TV,Cable TV,Internet,Wifi,Air conditioning,Poo...
# 2       TV,Cable TV,Wifi,Air conditioning,Kitchen,Pets...
# 3       TV,Wifi,Air conditioning,Kitchen,Pets live on ...
# 4       TV,Internet,Wifi,Air conditioning,Kitchen,Pets...
#                               ...
# 8042    TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8043    TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8044    TV,Cable TV,Wifi,Air conditioning,Pool,Kitchen...
# 8045    TV,Wifi,Air conditioning,Pool,Kitchen,Gym,Elev...
# 8046    TV,Wifi,Air conditioning,Pool,Kitchen,Gym,Elev...
# Name: amenities, Length: 7420, dtype: object

# %%
# getting a list of all amenities present

amenities_all = list(airbnb_data.amenities)
amenities_all = " ".join(amenities_all)

# %%
# list comprehension to get amenities into one list

amenities_list = [x.strip() for x in amenities_all.split(',')]

# %%
# taking a look at the top 20 amenities

amenities_list = pd.Series(amenities_list)
amenities_count_top20 = amenities_list.value_counts().head(20)

# %%
# there are 129 types of different amenities

print(len(set(amenities_list)))
(set(amenities_list))
# Out:
# 129
# {'',
#  '24-hour check-in',
#  'Accessible-height bed',
#  'Accessible-height toilet',
#  'Air conditioning',
#  'Air purifier',
#  'BBQ grill',
#  'Baby bath',
#  'Baby monitor',
#  'Babysitter recommendations',
#  'Baking sheet',
#  'Barbecue utensils',
#  'Bathtub',
#  'Beach essentials',
#  'Beachfront',
#  'Bed linens',
#  'Bread maker',
#  'Breakfast',
#  'Building staff',
#  'Buzzer/wireless intercom',
#  'Cable TV',
#  'Carbon monoxide detector',
#  'Cat(s)',
#  'Changing table',
#  'Children’s books and toys',
#  'Children’s dinnerware',
#  'Cleaning before checkout',
#  'Coffee maker',
#  'Cooking basics',
#  'Crib',
#  'Disabled parking spot',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Dryer',
#  'EV charger',
#  'Elevator',
#  'Essentials',
#  'Ethernet connection',
#  'Extra pillows and blankets',
#  'Extra space around bed',
#  'Family/kid friendly',
#  'Fire extinguisher',
#  'Fireplace guards',
#  'Firm mattress',
#  'First aid kit',
#  'Fixed grab bars for shower',
#  'Fixed grab bars for toilet',
#  'Flat path to guest entrance',
#  'Free parking on premises',
#  'Free street parking',
#  'Full kitchen',
#  'Game console',
#  'Garden or backyard',
#  'Ground floor access',
#  'Gym',
#  'Hair dryer',
#  'Handheld shower head',
#  'Hangers',
#  'Heating',
#  'High chair',
#  'Host greets you',
#  'Hot tub',
#  'Hot water',
#  'Hot water kettle',
#  'Indoor fireplace',
#  'Internet',
#  'Iron',
#  'Keypad',
#  'Kitchen',
#  'Kitchenette',
#  'Lake access',
#  'Laptop friendly workspace',
#  'Lock on bedroom door',
#  'Lockbox',
#  'Long term stays allowed',
#  'Luggage dropoff allowed',
#  'Microwave',
#  'Mobile hoist',
#  'No stairs or steps to enter',
#  'Other',
#  'Other pet(s)',
#  'Outlet covers',
#  'Oven',
#  'Pack ’n Play/travel crib',
#  'Paid parking off premises',
#  'Paid parking on premises',
#  'Patio or balcony',
#  'Pets allowed',
#  'Pets live on this property',
#  'Pocket wifi',
#  'Pool',
#  'Private bathroom',
#  'Private entrance',
#  'Private living room',
#  'Refrigerator',
#  'Room-darkening shades',
#  'Safety card',
#  'Self check-in',
#  'Shampoo',
#  'Shower chair',
#  'Shower gel',
#  'Single level home',
#  'Smart lock',
#  'Smoke detector',
#  'Smoking allowed',
#  'Stair gates',
#  'Step-free shower',
#  'Stove',
#  'Suitable for events',
#  'TV',
#  'Table corner guards',
#  'Trash can',
#  'Washer',
#  'Waterfront',
#  'Well-lit path to entrance',
#  'Wheelchair accessible',
#  'Wide clearance to shower',
#  'Wide doorway to guest bathroom',
#  'Wide entrance',
#  'Wide entrance for guests',
#  'Wide entryway',
#  'Wide hallways',
#  'Wifi',
#  'Window guards',
#  'toilet',
#  'translation missing: en.hosting_amenity_49',
#  'translation missing: en.hosting_amenity_50'}

# %%
amenities_count_top20
# Out:
# Air conditioning             7184
# Wifi                         7170
# Washer                       6543
# Essentials                   6541
# Kitchen                      6088
# Hangers                      6005
# Iron                         5612
# TV                           5418
# Hair dryer                   5405
# Shampoo                      5299
# Laptop friendly workspace    5232
# Elevator                     4802
# Dryer                        4674
# Hot water                    4396
# Lock on bedroom door         4110
# Pool                         3730
# Refrigerator                 3209
# Long term stays allowed      3098
# Gym                          3041
# Microwave                    2888
# dtype: int64

# %%
plt.figure(figsize=(12,8))
amenities_count_top20.plot(kind='bar')
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)
plt.show();

# %% [markdown]
# In the list above, there are 129 different types of listed amenities. I will extract the top 20, for further observation as to how having/not having a particular amenity would affect the price.
#
# These are the top 20 amenities:
#
# + Air conditioning
# + Wifi
# + Washer
# + Essentials
# + Kitchen
# + Hangers
# + Iron
# + TV
# + Hair dryer
# + Shampoo
# + Laptop friendly workspace
# + Elevator
# + Dryer
# + Hot water
# + Lock on bedroom door
# + Pool
# + Refrigerator
# + Long term stays allowed
# + Gym
# + Microwave

# %%
airbnb_data['air_con'] = pd.np.where(airbnb_data.amenities.str.contains('Air conditioning'),1,0)
airbnb_data['wifi'] = pd.np.where(airbnb_data.amenities.str.contains('Wifi'),1,0)
airbnb_data['washer'] = pd.np.where(airbnb_data.amenities.str.contains('Washer'),1,0)
airbnb_data['essentials'] = pd.np.where(airbnb_data.amenities.str.contains('Essentials'),1,0)
airbnb_data['kitchen'] = pd.np.where(airbnb_data.amenities.str.contains('Kitchen'),1,0)
airbnb_data['hangers'] = pd.np.where(airbnb_data.amenities.str.contains('Hangers'),1,0)
airbnb_data['iron'] = pd.np.where(airbnb_data.amenities.str.contains('Iron'),1,0)
airbnb_data['tv'] = pd.np.where(airbnb_data.amenities.str.contains('TV'),1,0)
airbnb_data['hair_dryer'] = pd.np.where(airbnb_data.amenities.str.contains('Hair dryer'),1,0)
airbnb_data['shampoo'] = pd.np.where(airbnb_data.amenities.str.contains('Shampoo'),1,0)
airbnb_data['laptop_workspace'] = pd.np.where(airbnb_data.amenities.str.contains('Laptop friendly workspace'),1,0)
airbnb_data['elevator'] = pd.np.where(airbnb_data.amenities.str.contains('Elevator'),1,0)
airbnb_data['dryer'] = pd.np.where(airbnb_data.amenities.str.contains('Dryer'),1,0)
airbnb_data['hot_water'] = pd.np.where(airbnb_data.amenities.str.contains('Hot water'),1,0)
airbnb_data['bedroom_lock'] = pd.np.where(airbnb_data.amenities.str.contains('Lock on bedroom door'),1,0)
airbnb_data['pool'] = pd.np.where(airbnb_data.amenities.str.contains('Pool'),1,0)
airbnb_data['refrigerator'] = pd.np.where(airbnb_data.amenities.str.contains('Refrigerator'),1,0)
airbnb_data['long_term_stays'] = pd.np.where(airbnb_data.amenities.str.contains('Long term stays allowed'),1,0)
airbnb_data['gym'] = pd.np.where(airbnb_data.amenities.str.contains('Gym'),1,0)
airbnb_data['microwave'] = pd.np.where(airbnb_data.amenities.str.contains('Microwave'),1,0)

# %% [markdown]
# Since I have categorized this into boolean categories, I will continue with the `amenities` EDA later on, looking at it as numerical features.

# %% [markdown]
# #### cancellation_policy

# %%
boxplot_(airbnb_data,'cancellation_policy', 'price', 'Cancellation Policy', 'Price, SGD',
        'Cancellation Policy Versus Price', 15, 5)


plt.xticks(rotation=45, fontsize = 17);

# %% [markdown]
# ### Numerical Features

# %%
# List out all the numerical features

num_features = airbnb_data.select_dtypes(include=[np.number])

# Return a subset of the DataFrame’s columns based on the column dtypes = numeric number

print(f' Total number of numeric features: {num_features.shape[1]}')
num_features.dtypes
# Out:
#  Total number of numeric features: 47
# id                          int64
# host_is_superhost           int64
# host_listings_count         int64
# host_identity_verified      int64
# latitude                  float64
# longitude                 float64
# is_location_exact           int64
# accommodates                int64
# bathrooms                 float64
# bedrooms                  float64
# beds                      float64
# price                     float64
# security_deposit          float64
# cleaning_fee              float64
# guests_included             int64
# extra_people              float64
# minimum_nights              int64
# availability_90             int64
# instant_bookable            int64
# host_active               float64
# phone                       int64
# email                       int64
# id_verification             int64
# review                      int64
# photo                       int64
# socials                     int64
# others                      int64
# air_con                     int64
# wifi                        int64
# washer                      int64
# essentials                  int64
# kitchen                     int64
# hangers                     int64
# iron                        int64
# tv                          int64
# hair_dryer                  int64
# shampoo                     int64
# laptop_workspace            int64
# elevator                    int64
# dryer                       int64
# hot_water                   int64
# bedroom_lock                int64
# pool                        int64
# refrigerator                int64
# long_term_stays             int64
# gym                         int64
# microwave                   int64
# dtype: object

# %% [markdown]
# #### Numerical features Vs Price
# There is a total of 45 numerical features. Taking a quick view of how they correlate with price.

# %%
# Numeric features correlation 

num_features_corr = airbnb_data.corr()[['price']]

#List of correction of sale price versus the 22 numerical features

num_features_corr.sort_values(by = ['price'], ascending = False).T
# Out:
#          price  accommodates  bedrooms  guests_included       tv  \
# price 1.000000      0.529974  0.469357         0.436916 0.389011
#
#        cleaning_fee  hair_dryer      gym     pool  shampoo  extra_people  \
# price      0.308378    0.289623 0.263628 0.238247 0.227269      0.213043
#
#        elevator     iron  kitchen  host_listings_count     beds    dryer  \
# price  0.212066 0.211907 0.208665             0.189790 0.186533 0.169763
#
#             id    photo  security_deposit  id_verification  hangers  \
# price 0.165649 0.157992          0.139498         0.139289 0.119056
#
#        availability_90  essentials  microwave  bathrooms  host_is_superhost  \
# price         0.104300    0.102163   0.101721   0.098317           0.097235
#
#        air_con  refrigerator  long_term_stays   others  laptop_workspace  \
# price 0.096480      0.091989         0.091470 0.090034          0.089070
#
#        is_location_exact  longitude  hot_water   washer    phone  socials  \
# price           0.034647   0.030816   0.029100 0.024926 0.020806 0.007881
#
#           wifi     email  instant_bookable    review  host_identity_verified  \
# price 0.000742 -0.023691         -0.050016 -0.074862               -0.110077
#
#        minimum_nights  host_active  bedroom_lock  latitude
# price       -0.110278    -0.141732     -0.166931 -0.236009

# %%
# To list out features with relatively strong postive and strong negative correlation with price:
strong_pos = num_features_corr['price'] > 0.3   
strong_neg = num_features_corr['price'] < -0.1 

strong_nfeatures = num_features_corr[strong_pos | strong_neg].index   # list of features with strong correlation to price
print(f'Total of {num_features_corr[strong_pos | strong_neg].shape[0] -1} stronger correlation features')

num_features_corr[strong_pos | strong_neg].sort_values(by = 'price', ascending = False).T
# Out:
# Total of 10 stronger correlation features
#          price  accommodates  bedrooms  guests_included       tv  \
# price 1.000000      0.529974  0.469357         0.436916 0.389011
#
#        cleaning_fee  host_identity_verified  minimum_nights  host_active  \
# price      0.308378               -0.110077       -0.110278    -0.141732
#
#        bedroom_lock  latitude
# price     -0.166931 -0.236009

# %%
# Unstack the correlation matrix (extract those with stronger positive correlation among the numeric features)

x = airbnb_data.corr().unstack()
x[ ((x>0.6) & (x<1.0)) ]
# Out:
# accommodates     bedrooms          0.671267
#                  beds              0.641707
# bedrooms         accommodates      0.671267
# beds             accommodates      0.641707
# host_active      review            0.619766
# id_verification  others            0.820342
# review           host_active       0.619766
# others           id_verification   0.820342
# pool             gym               0.745549
# refrigerator     microwave         0.864797
# gym              pool              0.745549
# microwave        refrigerator      0.864797
# dtype: float64

# %%
y = airbnb_data.corr().unstack()
y[ ((y<(-0.6)) & (y>(-1.0))) ]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# From the above, there is no negative correlation that reduces prices that is significant.

# %% [markdown]
# **Numeric features with correlation to Price**
#
# By going through the sorted list of stronger correlation features, we observed that there seems to be some correlation between the numeric features and price, with the highest correlation being at 0.52.
#
# 1. `accomodates` has the highest correlation with `price`.
#
# 2. `bedrooms` comes in as a close 2nd for correlation with `price`. However, it is also correlated to accomodates, which indicates that multicollinearity exists.
#
# 3. All the correlations do make some sense, where we would generally expect a higher price for the increase in number of `accomodates`, `bedrooms`, `guests_included` and presence of `tv`.

# %%
# ploting the histograms to show the distribution of numeric features

def hist_plot(feature, binsize, xlabel, title):
    plt.figure(figsize = (12,6));
    airbnb_data[feature].plot(kind = 'hist', bins = binsize, rwidth = 0.9, color = 'royalblue', alpha = 0.9);
    
    plt.xlabel(xlabel, fontsize = 14)
    plt.ylabel('Counts', fontsize = 14)
    plt.title(title, fontsize = 20)
    plt.grid(axis ='y', alpha = 0.6)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

# %%
# ploting the counts of true and false categories next to the median price for the category

def boolean_features(col, figsize=(8,3)):
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle(col, fontsize=15, y=1)
    plt.subplots_adjust(top=0.80) # So that the subtitle does not overlap with the ax plot titles
    
    airbnb_data.groupby(col).size().plot(kind='bar', ax=ax1, color=['darkslategray', 'mediumaquamarine'])
    ax1.set_xticklabels(labels=['false', 'true'], rotation=0)
    ax1.set_title('Category count', fontsize=12)
    ax1.set_xlabel('')
    
    airbnb_data.groupby(col).price.median().plot(kind='bar', ax=ax2, color=['darkslategray', 'mediumaquamarine'])
    ax2.set_xticklabels(labels=['false', 'true'], rotation=0)
    ax2.set_title('Log Median price (SGD)', fontsize=12)
    ax2.set_xlabel('')
    
    plt.show()

# %% [markdown]
# #### host_is_superhost

# %%
# taking a look at the relationship between host_is_superhost and median 
# price in that category

boolean_features('host_is_superhost')
print(airbnb_data.host_is_superhost.value_counts(normalize=True))
# Out:
# 0   0.839353
# 1   0.160647
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# #### host_listings_count

# %%
# distribution of the 'host_listings_count'

hist_plot('host_listings_count', 15, 'Number of host_listings_count', 'Distribution of host_listings_count')

# the number of host_listings_count falls below 50

# %% [markdown]
# #### host_identity_verified

# %%
# taking a look at the relationship between host_identity_verified and median 
# price in that category

boolean_features('host_identity_verified')
print(airbnb_data.host_identity_verified.value_counts(normalize=True))
# Out:
# 0   0.767116
# 1   0.232884
# Name: host_identity_verified, dtype: float64

# %% [markdown]
# #### is_location_exact

# %%
# taking a look at the relationship between is_location_exact and median 
# price in that category

boolean_features('is_location_exact')
print(airbnb_data.is_location_exact.value_counts(normalize=True))
# Out:
# 1   0.721294
# 0   0.278706
# Name: is_location_exact, dtype: float64

# %% [markdown]
# #### accomodates

# %%
# distribution of the 'accommodates'

hist_plot('accommodates', 15, 'Number of accommodates', 'Distribution of accommodates')

# the number of accommodates falls mainly between 2-3

# %% [markdown]
# #### bathrooms

# %%
# distribution of the 'abathrooms'

hist_plot('bathrooms', 15 , 'Number of bathrooms', 'Distribution of bathrooms')

# the number of bathrooms falls mainly between 0-2

# %% [markdown]
# #### bedrooms

# %%
# distribution of the 'bedrooms'

hist_plot('bedrooms', 20, 'Number of bedrooms', 'Distribution of bedrooms')

# the number of bedrooms falls mainly between 1-2

# %% [markdown]
# #### beds

# %%
# distribution of the 'beds'

hist_plot('beds', 20, 'Number of beds', 'Distribution of beds')

# the number of beds falls mainly between 1-5.

# %% [markdown]
# #### security_deposit

# %%
# distribution of the 'security_deposit'

hist_plot('security_deposit', 20, 'Price distribution of security_deposit', 'Distribution of security_deposit')

# the number of security_deposit falls mainly below $500

# %% [markdown]
# #### cleaning_fee

# %%
# distribution of the 'cleaning_fee'

hist_plot('cleaning_fee', 20, 'Price distribution of cleaning fee', 'Distribution of cleaning fee')

# the number of cleaning_fee falls mainly below $500

# %% [markdown]
# #### guests_included

# %%
# distribution of the 'guests_included'

hist_plot('guests_included', 20, 'Number of guests_included', 'Distribution of guests_included')

# the number of guests_included is mainly 5 and below

# %% [markdown]
# #### extra_people

# %%
# distribution of the 'extra_people'

hist_plot('extra_people', 20, 'Number of extra_people', 'Distribution of extra_people')

# the number of extra_people is mainly 20 and below

# %% [markdown]
# #### availability_90

# %%
# distribution of the 'availability_90'

hist_plot('availability_90', 20, 'Number of availability_90', 'Distribution of availability_90')

# the number of availability_90 is mainly 20 and below

# %% [markdown]
# #### instant_bookable

# %%
# taking a look at the relationship between instant_bookable and median 
# price in that category

boolean_features('instant_bookable')
print(airbnb_data.instant_bookable.value_counts(normalize=True))
# Out:
# 0   0.524259
# 1   0.475741
# Name: instant_bookable, dtype: float64

# %% [markdown]
# #### host_active

# %%
# distribution of the 'host_active'

hist_plot('host_active', 20, 'Number of host_active', 'Distribution of host_active')

# the number of host_active is mainly 20 and below

# %% [markdown]
# #### phone

# %%
# taking a look at the relationship between phone and median
# price in that category

boolean_features('phone')
print(airbnb_data.phone.value_counts(normalize=True))
# Out:
# 1   0.994879
# 0   0.005121
# Name: phone, dtype: float64

# %% [markdown]
# #### email

# %%
# taking a look at the relationship between email and median 
# price in that category

boolean_features('email')
print(airbnb_data.email.value_counts(normalize=True))
# Out:
# 1   0.904582
# 0   0.095418
# Name: email, dtype: float64

# %% [markdown]
# #### id_verification

# %%
# taking a look at the relationship between id_verfication and median
# price in that category

boolean_features('id_verification')
print(airbnb_data.id_verification.value_counts(normalize=True))
# Out:
# 1   0.730997
# 0   0.269003
# Name: id_verification, dtype: float64

# %% [markdown]
# #### review

# %%
# taking a look at the relationship between review and median
# price in that category

boolean_features('review')
print(airbnb_data.review.value_counts(normalize=True))
# Out:
# 1   0.593935
# 0   0.406065
# Name: review, dtype: float64

# %% [markdown]
# #### photo

# %%
# taking a look at the relationship between photo and median review
# price in that category

boolean_features('photo')
print(airbnb_data.photo.value_counts(normalize=True))
# Out:
# 0   0.590296
# 1   0.409704
# Name: photo, dtype: float64

# %% [markdown]
# #### socials

# %%
# taking a look at the relationship between socials and median review
# price in that category

boolean_features('socials')
print(airbnb_data.socials.value_counts(normalize=True))
# Out:
# 0   0.849191
# 1   0.150809
# Name: socials, dtype: float64

# %% [markdown]
# #### others

# %%
# taking a look at the relationship between others and median review
# price in that category

boolean_features('others')
print(airbnb_data.others.value_counts(normalize=True))
# Out:
# 1   0.665903
# 0   0.334097
# Name: others, dtype: float64

# %% [markdown]
# #### air_con

# %%
# taking a look at the relationship between air_con and median review
# price in that category

boolean_features('air_con')
print(airbnb_data.air_con.value_counts(normalize=True))
# Out:
# 1   0.968194
# 0   0.031806
# Name: air_con, dtype: float64

# %% [markdown]
# #### wifi

# %%
# taking a look at the relationship between wifi and median review
# price in that category

boolean_features('wifi')
print(airbnb_data.wifi.value_counts(normalize=True))
# Out:
# 1   0.966307
# 0   0.033693
# Name: wifi, dtype: float64

# %% [markdown]
# #### washer

# %%
# taking a look at the relationship between washer and median review
# price in that category

boolean_features('washer')
print(airbnb_data.washer.value_counts(normalize=True))
# Out:
# 1   0.881806
# 0   0.118194
# Name: washer, dtype: float64

# %% [markdown]
# #### essentials

# %%
# taking a look at the relationship between essentials and median review
# price in that category

boolean_features('essentials')
print(airbnb_data.essentials.value_counts(normalize=True))
# Out:
# 1   0.881536
# 0   0.118464
# Name: essentials, dtype: float64

# %% [markdown]
# #### kitchen

# %%
# taking a look at the relationship between kitchen and median review
# price in that category

boolean_features('kitchen')
print(airbnb_data.kitchen.value_counts(normalize=True))
# Out:
# 1   0.820485
# 0   0.179515
# Name: kitchen, dtype: float64

# %% [markdown]
# #### hangers

# %%
# taking a look at the relationship between kitchen and median review
# price in that category

boolean_features('kitchen')
print(airbnb_data.kitchen.value_counts(normalize=True))
# Out:
# 1   0.820485
# 0   0.179515
# Name: kitchen, dtype: float64

# %% [markdown]
# #### iron

# %%
# taking a look at the relationship between iron and median review
# price in that category

boolean_features('iron')
print(airbnb_data.iron.value_counts(normalize=True))
# Out:
# 1   0.756334
# 0   0.243666
# Name: iron, dtype: float64

# %% [markdown]
# #### tv

# %%
# taking a look at the relationship between tv and median review
# price in that category

boolean_features('tv')
print(airbnb_data.tv.value_counts(normalize=True))
# Out:
# 1   0.735445
# 0   0.264555
# Name: tv, dtype: float64

# %% [markdown]
# #### hair_dryer

# %%
# taking a look at the relationship between hair_dryer and median review
# price in that category

boolean_features('hair_dryer')
print(airbnb_data.hair_dryer.value_counts(normalize=True))
# Out:
# 1   0.728437
# 0   0.271563
# Name: hair_dryer, dtype: float64

# %% [markdown]
# #### shampoo

# %%
# taking a look at the relationship between shampoo and median review
# price in that category

boolean_features('shampoo')
print(airbnb_data.shampoo.value_counts(normalize=True))
# Out:
# 1   0.714151
# 0   0.285849
# Name: shampoo, dtype: float64

# %% [markdown]
# #### laptop_workspace

# %%
# taking a look at the relationship between laptop_workspace and median review
# price in that category

boolean_features('laptop_workspace')
print(airbnb_data.laptop_workspace.value_counts(normalize=True))
# Out:
# 1   0.705121
# 0   0.294879
# Name: laptop_workspace, dtype: float64

# %% [markdown]
# #### elevator

# %%
# taking a look at the relationship between elevator and median review
# price in that category

boolean_features('elevator')
print(airbnb_data.elevator.value_counts(normalize=True))
# Out:
# 1   0.647170
# 0   0.352830
# Name: elevator, dtype: float64

# %% [markdown]
# #### dryer

# %%
# taking a look at the relationship between dryer and median review
# price in that category

boolean_features('dryer')
print(airbnb_data.dryer.value_counts(normalize=True))
# Out:
# 1   0.629919
# 0   0.370081
# Name: dryer, dtype: float64

# %% [markdown]
# #### hot_water

# %%
# taking a look at the relationship between hot_water and median review
# price in that category

boolean_features('hot_water')
print(airbnb_data.hot_water.value_counts(normalize=True))
# Out:
# 1   0.592453
# 0   0.407547
# Name: hot_water, dtype: float64

# %% [markdown]
# #### bedroom_lock

# %%
# taking a look at the relationship between bedroom_lock and median review
# price in that category

boolean_features('bedroom_lock')
print(airbnb_data.bedroom_lock.value_counts(normalize=True))
# Out:
# 1   0.553908
# 0   0.446092
# Name: bedroom_lock, dtype: float64

# %% [markdown]
# #### pool

# %%
# taking a look at the relationship between pool and median review
# price in that category

boolean_features('pool')
print(airbnb_data.pool.value_counts(normalize=True))
# Out:
# 1   0.502695
# 0   0.497305
# Name: pool, dtype: float64

# %% [markdown]
# #### refrigerator

# %%
# taking a look at the relationship between refrigerator and median review
# price in that category

boolean_features('refrigerator')
print(airbnb_data.refrigerator.value_counts(normalize=True))
# Out:
# 0   0.567520
# 1   0.432480
# Name: refrigerator, dtype: float64

# %% [markdown]
# #### long_term_stays

# %%
# taking a look at the relationship between long_term_stays and median review
# price in that category

boolean_features('long_term_stays')
print(airbnb_data.long_term_stays.value_counts(normalize=True))
# Out:
# 0   0.582480
# 1   0.417520
# Name: long_term_stays, dtype: float64

# %% [markdown]
# #### gym

# %%
# taking a look at the relationship between gym and median review
# price in that category

boolean_features('gym')
print(airbnb_data.gym.value_counts(normalize=True))
# Out:
# 0   0.590162
# 1   0.409838
# Name: gym, dtype: float64

# %% [markdown]
# #### microwave

# %%
# taking a look at the relationship between microwave and median review
# price in that category

boolean_features('microwave')
print(airbnb_data.microwave.value_counts(normalize=True))
# Out:
# 0   0.610782
# 1   0.389218
# Name: microwave, dtype: float64

# %% [markdown]
# ### Feature Engineering
# Adding some additional features based on our understanding.

# %%
airbnb_data['bedrooms_per_accommodates'] = airbnb_data['bedrooms'] / airbnb_data['accommodates']

# %% [markdown]
# ### Preparing data for Modelling

# %%
airbnb_data = airbnb_data.drop(columns = ['amenities',
                                          'host_since', 
                                          'host_verifications'])

# %%
airbnb_data.to_csv('../data/listings_cleaned.csv', index = False)
